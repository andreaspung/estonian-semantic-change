# %% [markdown]
# # Training embeddings
#
# ## Training word2vec models

# %%
import numpy as np
import pickle
import gensim
from gensim.models import Word2Vec
from scipy.stats import pearsonr
from svd2vec import svd2vec
from os import listdir
from os.path import isfile, join
from scipy.spatial.distance import cosine
from collections import Counter

# %%
gensim.__version__
# Out:
# '4.0.1'

# %%
DATA_DIR = "./corpus/lemmas" #select either words or lemmas
MODEL_DIR = "./models/word2vec"

# %%
# Finding all filenames in the data folder
all_files = [f for f in listdir(DATA_DIR) if isfile(join(DATA_DIR, f))]
all_files = [filename for filename in all_files if filename[-4:] not in [".zip", "r.gz"]]

# %%
all_files
# Out:
# ['1890_aja_lemmas.txt',
#  '1890_ilu_lemmas.txt',
#  '1900_aja_lemmas.txt',
#  '1900_ilu_lemmas.txt',
#  '1910_aja_lemmas.txt',
#  '1910_ilu_lemmas.txt',
#  '1930_aja_lemmas.txt',
#  '1930_ilu_lemmas.txt',
#  '1950_aja_lemmas.txt',
#  '1950_ilu_lemmas.txt',
#  '1960_aja_lemmas.txt',
#  '1960_ilu_lemmas.txt',
#  '1970_aja_lemmas.txt',
#  '1970_ilu_lemmas.txt',
#  '1980_aja_lemmas.txt',
#  '1980_ilu_lemmas.txt',
#  '1980_muu_lemmas.txt',
#  '1980_tea_lemmas.txt',
#  '1990e_aja_lemmas.txt',
#  '1990_ilu_lemmas.txt']

# %%
decades = [1890, 1900, 1910, 1930, 1950, 1960, 1970, 1980, 1990] #1920 is a different data domain, 1940 was not included

# %%
# Training word2vec
def train_word2vec(vector_size=100, window=5, min_count=1, sg=1, negative=5):
    models = {}
    for decade in decades:
        chosen_files = [filename for filename in all_files if int(filename[:4]) == decade]
        #print(chosen_files)
        sentences = []
        for filename in chosen_files:
            with open(DATA_DIR + "/" + filename, mode="r", encoding="utf8") as f:
                for row in f:
                    row = row.strip().split(" ")
                    #row = [word.replace("w", "v") for word in row] #normalizing the old style of writing
                    #row = [word.replace("ß", "s") for word in row] #normalizing the old style of writing
                    sentences.append(row)
        # https://radimrehurek.com/gensim/models/word2vec.html#gensim.models.word2vec.Word2Vec
        model = Word2Vec(sentences=sentences, vector_size=vector_size, window=window, min_count=min_count, sg=sg, negative=negative, workers=8)
        models[decade] = model
        model.save(f"{MODEL_DIR}/word2vec_{vector_size}d_{window}w_{min_count}mc_{sg}algo_{negative}neg_{decade}.model")
    return models

models = train_word2vec()

# %%
best_val = 0
best_params = None
for vector_size in [100,200,300]:
    for window in [2,5,10]:
        for min_count in [2, 3, 5, 10]:
            for sg in [1]:
                for negative in [0, 3, 5, 10]:
                    params = {"vector_size": vector_size, "window": window, "min_count": min_count, "negative": negative}
                    print(params)
                    models = train_word2vec(vector_size=vector_size, window=window, min_count=min_count, sg=sg, negative=negative)
                    val = evaluate_word2vec(models)
                    
                    if val > best_val:
                        best_val = val
                        best_params = params
                        print("Found new best value of", best_val, "with parameters", best_params)
# Out:
# {'vector_size': 100, 'window': 2, 'min_count': 2, 'negative': 0}
# 1890 (-0.3562401306368913, 0.11295548853307931)
# 1900 (-0.08929424375368605, 0.6644419376080374)
# 1890 (-0.11288587237383979, 0.7410482676487833)
# 1900 (-0.20611125197887042, 0.594695509032909)
# 1910 (0.2061668470731346, 0.695131266478139)
# 1930 (0.19961030957356493, 0.3611638663768616)
# 1950 (0.27704439535187436, 0.3594736350620097)
# 1960 (-0.6259477140713265, 0.02945604552069708)
# 1970 (-0.055587958236609544, 0.8265899864934831)
# 1980 (0.01727891476483625, 0.9239657612929465)
# 1990 (0.15990639834544668, 0.38199682040573846)
# {'vector_size': 300, 'window': 10, 'min_count': 10, 'negative': 3}
# 1890 (0.212303695970318, 0.5308400639611717)
# 1900 (0.6816008637665232, 0.0431785382073305)
# 1910 (0.548689414299961, 0.2595601162118856)
# 1930 (-0.016625279698882715, 0.9399835333256028)
# 1950 (-0.1631842871997188, 0.594256487216064)
# 1960 (0.6674607211071063, 0.017714682574518886)
# 1970 (0.3528575991268296, 0.15092894929306902)
# 1980 (0.2059014817473452, 0.2503183612924692)
# 1990 (0.2470759507103342, 0.17278441849692422)
# {'vector_size': 300, 'window': 10, 'min_count': 10, 'negative': 5}
# 1890 (0.16646757983101285, 0.624700950100803)
# 1900 (0.727232120251931, 0.026403539624193152)
# 1910 (0.5481765103798648, 0.2600980662027863)
# 1930 (0.07400303201194805, 0.7371915432192521)
# 1950 (-0.2064899036510302, 0.4985041007332655)
# 1960 (0.6298840799443323, 0.028151980876110552)
# 1970 (0.3699552777293346, 0.13075873715476657)
# 1980 (0.20547432564692136, 0.2513240971496255)
# 1990 (0.2502507071491476, 0.16715432318705692)
# {'vector_size': 300, 'window': 10, 'min_count': 10, 'negative': 10}
# 1890 (0.24471501683247862, 0.4683085381272501)
# 1900 (0.7123383274103777, 0.03129615625349997)
# 1910 (0.34589188954474387, 0.5018536259213651)
# 1930 (0.036242113885651996, 0.8695960036546481)
# 1950 (-0.25035584692463714, 0.4093838508323233)
# 1960 (0.6340987318325522, 0.026802463720778512)
# 1970 (0.3212913301567546, 0.19358074660260205)
# 1980 (0.2245535686763411, 0.20899212598187744)
# 1990 (0.3042970584755954, 0.0903981657970754)

# %%
models[1990].wv.most_similar("tere")
# Out:
# [('rinkner', 0.9569980502128601),
#  ('glebke', 0.9474722743034363),
#  ('keavin', 0.944699227809906),
#  ('potapov', 0.9369103312492371),
#  ('mürt', 0.9346433281898499),
#  ('peetrus', 0.9338791966438293),
#  ('valjusti', 0.9316402077674866),
#  ('seepeale', 0.9299307465553284),
#  ('adu', 0.929161012172699),
#  ('tom', 0.929135799407959)]

# %% [markdown]
# ## Training SVD vectors (from PPMI)

# %%
DATA_DIR = "./corpus/lemmas" #select either words or lemmas
MODEL_DIR = "./models/svd"

all_files = [f for f in listdir(DATA_DIR) if isfile(join(DATA_DIR, f))]
all_files = [filename for filename in all_files if filename[-4:] not in [".zip", "r.gz"]]

# %%
all_files
# Out:
# ['1890_aja_lemmas.txt',
#  '1890_ilu_lemmas.txt',
#  '1900_aja_lemmas.txt',
#  '1900_ilu_lemmas.txt',
#  '1910_aja_lemmas.txt',
#  '1910_ilu_lemmas.txt',
#  '1930_aja_lemmas.txt',
#  '1930_ilu_lemmas.txt',
#  '1950_aja_lemmas.txt',
#  '1950_ilu_lemmas.txt',
#  '1960_aja_lemmas.txt',
#  '1960_ilu_lemmas.txt',
#  '1970_aja_lemmas.txt',
#  '1970_ilu_lemmas.txt',
#  '1980_aja_lemmas.txt',
#  '1980_ilu_lemmas.txt',
#  '1980_muu_lemmas.txt',
#  '1980_tea_lemmas.txt',
#  '1990e_aja_lemmas.txt',
#  '1990_ilu_lemmas.txt']

# %%
def train_ppmisvd(size=200, window=10, min_count=10):
    svd_models = {}
    for decade in decades:
        chosen_files = [filename for filename in all_files if int(filename[:4]) == decade]
        #print(chosen_files)

        sentences = []
        for filename in chosen_files:
            with open(DATA_DIR + "/" + filename, mode="r", encoding="utf8") as f:
                for row in f:
                    row = row.strip().split(" ")
                    #row = [word.replace("w", "v") for word in row] #normalizing the old style of writing
                    #row = [word.replace("ß", "s") for word in row] #normalizing the old style of writing
                    sentences.append(row)
        # https://valentinp72.github.io/svd2vec/svd2vec.html#svd2vec.svd2vec
        #training run 1 - model = svd2vec(sentences, size=150, window=2, min_count=1, verbose=False, workers=8) svd_year.model
        #training run 2 - model = svd2vec(sentences, size=200, window=5, min_count=2, verbose=False, workers=8)
        model = svd2vec(sentences, size=size, window=window, min_count=min_count, verbose=False, workers=8)
        svd_models[decade] = model
        model.save(f"{MODEL_DIR}/svd_{size}d_{window}w_{min_count}mc_{decade}.model") #UPDATE!
    return svd_models

# %%
best_val = 0
best_params = None
for vector_size in [200]:
    for window in [2,5,10]:
        for min_count in [2, 3, 5, 10]:
            params = {"vector_size": vector_size, "window": window, "min_count": min_count}
            print(params)
            models = train_ppmisvd(size=vector_size, window=window, min_count=min_count)
            val = evaluate_ppmisvd(models)
            print(val)

            if val > best_val:
                best_val = val
                best_params = params
                print("Found new best value of", best_val, "with parameters", best_params)
# Out:
# {'vector_size': 200, 'window': 2, 'min_count': 2}
# 1890 (0.07294672535787637, 0.7533437110179739)
# 1900 (0.03685594103962618, 0.858136408774903)
# 1910 (0.04152047370536671, 0.8185433449463597)
# 1930 (0.131196900273934, 0.4259638681716837)
# 1950 (0.19460390592930948, 0.28583949037456213)
# 1960 (0.06461517239049959, 0.7344376840034168)
# 1970 (-0.10087147489744994, 0.5764707326603432)
# 1980 (0.014567102042378544, 0.9200228489278185)
# 1990 (-0.03354400344983666, 0.8350708146346542)
# 0.0703151237319507
# Found new best value of 0.0703151237319507 with parameters {'vector_size': 200, 'window': 2, 'min_count': 2}
# {'vector_size': 200, 'window': 2, 'min_count': 3}
# 1890 (-0.20137143574821395, 0.3945776554284753)
# 1900 (0.07711885689395838, 0.761012494224143)
# 1910 (0.11747299470443856, 0.5676454494119455)
# 1930 (-0.08853625255648451, 0.6299064175246979)
# 1950 (-0.11546747333704246, 0.5584788426933373)
# 1960 (0.3780745792691157, 0.06239990272821291)
# 1970 (-0.22061463278973265, 0.23301968644657706)
# 1980 (0.15193044519880017, 0.29221836658360484)
#  ['tiido', 0.9833094800157481],
#  ['mt-352', 0.9831037333916005],
#  ['novelliti', 0.9825522712033941],
#  ['träni', 0.9807039307605041],
#  ['vabaõhulaev', 0.9807039307605039]]

# %%
svd_models[1970].similarity("inimene", "sukk")
# Out:
# -0.001326078622183164

# %%
# I did not use it in the end
def ppmi(sentences, window=2):
    unigram_counts = Counter([item for sublist in sentences for item in sublist])
    
    co_occ = Counter()
    for sentence in sentences:
        for i, word in enumerate(sentence): # do not count occurrences over sentence border
            context_idx = [j for j in range(i-window, i+window+1) if 0 <= j <= len(sentence) - 1  and i != j]
            
            for j in context_idx:
                co_occ[(word, sentence[j])] += 1
                co_occ[(sentence[j], word)] += 1
    
    return co_occ

# %%
sentence = ["tere", "mina", "olen", "üks", "väga", "pikk", "lause"]
window=4
for i, word in enumerate(sentence): # do not count occurrences over sentence border
    context_idx = [j for j in range(i-window, i+window+1) if 0 <= j <= len(sentence) - 1  and i != j]
    print(i, context_idx)
# Out:
# 0 [1, 2, 3, 4]
# 1 [0, 2, 3, 4, 5]
# 2 [0, 1, 3, 4, 5, 6]
# 3 [0, 1, 2, 4, 5, 6]
# 4 [0, 1, 2, 3, 5, 6]
# 5 [1, 2, 3, 4, 6]
# 6 [2, 3, 4, 5]

# %% [markdown]
# ## Reading in models from files

# %%
#word2vec

#%word2vec: Found new best value of 0.3487609631693991 with parameters {'vector_size': 200, 'window': 10, 'min_count': 10, 'negative': 3}

# Finding all filenames in the data folder
MODEL_DIR = "./models/word2vec"
all_files = [f for f in listdir(MODEL_DIR) if isfile(join(MODEL_DIR, f))]
all_files = [filename for filename in all_files if filename.startswith("word2vec_200d_10w_10mc_1algo_3neg_") and filename[-5:] == "model" and filename[-4:] not in [".zip", "r.gz"] and "aligned" not in filename]
models = {}

for file in all_files:
    print(file)
    model = Word2Vec.load(f"{MODEL_DIR}/{file}")
    models[int(file[-10:-6])] = model
# Out:
# word2vec_200d_10w_10mc_1algo_3neg_1890.model
# word2vec_200d_10w_10mc_1algo_3neg_1900.model
# word2vec_200d_10w_10mc_1algo_3neg_1910.model
# word2vec_200d_10w_10mc_1algo_3neg_1930.model
# word2vec_200d_10w_10mc_1algo_3neg_1950.model
# word2vec_200d_10w_10mc_1algo_3neg_1960.model
# word2vec_200d_10w_10mc_1algo_3neg_1970.model
# word2vec_200d_10w_10mc_1algo_3neg_1980.model
# word2vec_200d_10w_10mc_1algo_3neg_1990.model

# %%
models
# Out:
# {1890: <gensim.models.word2vec.Word2Vec at 0x11e581e88b0>,
#  1900: <gensim.models.word2vec.Word2Vec at 0x11e581e8130>,
#  1910: <gensim.models.word2vec.Word2Vec at 0x11e686240a0>,
#  1930: <gensim.models.word2vec.Word2Vec at 0x11e68624400>,
#  1950: <gensim.models.word2vec.Word2Vec at 0x11e21cfd100>,
#  1960: <gensim.models.word2vec.Word2Vec at 0x11e21cfd760>,
#  1970: <gensim.models.word2vec.Word2Vec at 0x11e21cfd7c0>,
#  1980: <gensim.models.word2vec.Word2Vec at 0x11e61211100>,
#  1990: <gensim.models.word2vec.Word2Vec at 0x11e612112e0>}

# %%
#svd
#%SVD: Found new best value of 0.2565087015193734 with parameters {'vector_size': 200, 'window': 5, 'min_count': 5}
# Finding all filenames in the data folder
MODEL_DIR = "./models/svd"
all_files = [f for f in listdir(MODEL_DIR) if isfile(join(MODEL_DIR, f))]
all_files = [filename for filename in all_files if filename.startswith("svd_200d_5w_5mc_") and filename[-5:] == "model" and filename[-4:] not in [".zip", "r.gz"] and "aligned" not in filename and "diff" not in filename]
svd_models = {}

for file in all_files:
    print(file)
    model = svd2vec.load(f"{MODEL_DIR}/{file}")
    svd_models[int(file[-10:-6])] = model
# Out:
# svd_200d_5w_5mc_1890.model
# svd_200d_5w_5mc_1900.model
# svd_200d_5w_5mc_1910.model
# svd_200d_5w_5mc_1930.model
# svd_200d_5w_5mc_1950.model
# svd_200d_5w_5mc_1960.model
# svd_200d_5w_5mc_1970.model
# svd_200d_5w_5mc_1980.model
# svd_200d_5w_5mc_1990.model

# %%
svd_models
# Out:
# {1890: <svd2vec.core.svd2vec at 0x11e21cfd280>,
#  1900: <svd2vec.core.svd2vec at 0x11e21cfd2b0>,
#  1910: <svd2vec.core.svd2vec at 0x11e581e8730>,
#  1930: <svd2vec.core.svd2vec at 0x11e581e8850>,
#  1950: <svd2vec.core.svd2vec at 0x11e6e439550>,
#  1960: <svd2vec.core.svd2vec at 0x11e6e439cd0>,
#  1970: <svd2vec.core.svd2vec at 0x11e581e8a90>,
#  1980: <svd2vec.core.svd2vec at 0x11e5361f550>,
#  1990: <svd2vec.core.svd2vec at 0x11e5361f0a0>}

# %%
#svd
# Finding all filenames in the data folder
MODEL_DIR = "./models/svd"
all_files = [f for f in listdir(MODEL_DIR) if isfile(join(MODEL_DIR, f))]
all_files = [filename for filename in all_files if filename[-5:] == "model" and filename[-4:] not in [".zip", "r.gz"] and "aligned" not in filename]
svd_models = {}

for file in all_files:
    print(file)
    svd_model = svd2vec.load(f"{MODEL_DIR}/{file}")
    svd_model.save_word2vec_format(f"{MODEL_DIR}/diff_{file}")
    #model = Word2Vec.load(f"{MODEL_DIR}/{file}")
    #models[int(file[:4])] = model
# Out:
# svd_1890.model
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18872/688691503.py in <module>
#       9     print(file)
#      10     svd_model = svd2vec.load(f"{MODEL_DIR}/{file}")
# ---> 11     svd_model.save_word2vec_format(f"{MODEL_DIR}/diff_{file}")
#      12     #model = Word2Vec.load(f"{MODEL_DIR}/{file}")
#      13     #models[int(file[:4])] = model
#
# C:\ProgramData\Anaconda3\envs\estonian-semantic-change\lib\site-packages\svd2vec\core.py in save_word2vec_format(self, path)
#     380             for word in self.vocabulary:
#     381                 values = " ".join(["{:.6f}".format(e) for e in self.vector_w(word)])
# --> 382                 print(word + " " + values, file=f)
#     383
#     384     #####
#
# C:\ProgramData\Anaconda3\envs\estonian-semantic-change\lib\encodings\cp1257.py in encode(self, input, final)
#      17 class IncrementalEncoder(codecs.IncrementalEncoder):
#      18     def encode(self, input, final=False):
# ---> 19         return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#      20
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\xe1' in position 2: character maps to <undefined>

# %%
svd_models.pop(1970)

# %%
svd_models[1950].words
# Out:
# ['ja',
#  'olema',
#  'see',
#  'tema',
#  'et',
#  'ei',
#  'mina',
#  'mis',
#  'töö',
#  'oma',
#  'nõukogu',
#  'kui',
#  'kolhoos',
#  'võtma',
#  'suur',
#  'ka',
#  'kes',
#  'kõik',
#  'sina',
#  'aasta',
#  'nagu',
#  'juba',
#  'pidama',
#  'nsv',
#  'ning',
#  'andma',
#  'rahvas',
#  'teine',
#  'noor',
#  'üks',
#  'veel',
#  'aeg',
#  'aga',
#  'inimene',
#  'uus',
#  'plaan',
#  'vastu',
#  'tulema',
#  'saama',
#  'nüüd',
#  'mitte',
#  'tegema',
#  'maa',
#  'kuid',
#  'ameerika',
#  'ise',
#  'liit',
#  'jääma',
#  'läbi',
#  'siis',
#  'küsimus',
#  'esimene',
#  'näitama',
#  'toimuma',
#  'iga',
#  'sotsialistlik',
#  'kogu',
#  'osa',
#  '.',
#  'eesti',
#  'töötaja',
#  'võitlus',
#  'hakkama',
#  'sm',
#  'võistlus',
#  'linn',
#  'praegu',
#  'kaks',
#  'panema',
#  'nii',
#  'stalin',
#  'partei',
#  'kommunistlik',
#  'valitsus',
#  'ütlema',
#  'vald',
#  'nägema',
#  'tass',
#  'poolt',
#  'kolm',
#  'arv',
#  'päev',
#  'töötama',
#  'ette',
#  'tahtma',
#  'võima',
#  'vaid',
#  'täitmine',
#  'kõige',
#  'vabariik',
#  'riik',
#  'eest',
#  'ainult',
#  'siin',
#  'palju',
#  'sama',
#  'tundma',
#  'teatama',
#  'minema',
#  'kohta',
#  'rida',
#  'kus',
#  'mõni',
#  'või',
#  'tallinn',
#  'ala',
#  'seltsimees',
#  'samuti',
#  'jooksul',
#  'kolhoosnik',
#  'sest',
#  'välja',
#  'käesolev',
#  'otsus',
#  'kunst',
#  'rubla',
#  'peale',
#  'mai',
#  'põllumajandus',
#  'saksa',
#  'aastapäev',
#  'üle',
#  'juhataja',
#  'kell',
#  'alles',
#  'enam',
#  'tööline',
#  'mitu',
#  'sõda',
#  'huvi',
#  'eriti',
#  'ülesanne',
#  'silm',
#  'miski',
#  'olukord',
#  'raske',
#  'esindaja',
#  'poliitiline',
#  'elu',
#  'a.',
#  'liige',
#  'parim',
#  'kuu',
#  'kord',
#  'sovhoos',
#  'ettevõte',
#  'nõudma',
#  'jõud',
#  'pärast',
#  'püüdma',
#  'laskma',
#  'tulemus',
#  'asuma',
#  'valimine',
#  'astuma',
#  'hulgas',
#  'põld',
#  'raamat',
#  'saavutama',
#  'hea',
#  'tee',
#  'teater',
#  'saatma',
#  'vaatama',
#  'juht',
#  'riiklik',
#  'kasutama',
#  'tagasi',
#  'p',
#  'ega',
#  'oktoober',
#  'tõstmine',
#  'a',
#  'v.',
#  'tähelepanu',
#  'esinema',
#  'külanõukogu',
#  'küsima',
#  'viimane',
#  'presiidium',
#  'moskva',
#  'miljon',
#  'traktorijaam',
#  'hulk',
#  'organiseerima',
#  'kohustus',
#  'kohustama',
#  'märkima',
#  'rahu',
#  'juures',
#  'väike',
#  'kas',
#  'kuna',
#  'esimees',
#  'sõna',
#  'enne',
#  'tubli',
#  'elama',
#  'ees',
#  'seisma',
#  'ulatus',
#  'täitma',
#  'kohalik',
#  'minister',
#  'ära',
#  'juhtimine',
#  'jätma',
#  'edasi',
#  'alla',
#  'mõistma',
#  'puškin',
#  'vajadus',
#  'keel',
#  'üldse',
#  'isegi',
#  'ootama',
#  'edukalt',
#  'kutsuma',
#  'tõus',
#  'kool',
#  'organisatsioon',
#  'avaldus',
#  'demokraatlik',
#  'jätkama',
#  'b',
#  'kalev',
#  'kevad',
#  'saabuma',
#  'üksik',
#  'töötav',
#  'korraldama',
#  'esitama',
#  'tegevus',
#  'tähendama',
#  'järgmine',
#  'täna',
#  'teadma',
#  'endine',
#  'aitama',
#  'kuidas',
#  'brigaad',
#  'ajaleht',
#  'poiss',
#  'ukraina',
#  'muutuma',
#  'küll',
#  'süda',
#  'täielikult',
#  'rohkem',
#  'eesrindlik',
#  'ehitama',
#  'saksamaa',
#  'vägi',
#  'pool',
#  'kindlustama',
#  'neli',
#  'ministeerium',
#  'looma',
#  'käsi',
#  'mees',
#  'küla',
#  'sekretär',
#  'rajoon',
#  'käima',
#  'tuba',
#  'tänav',
#  'võimalus',
#  'koht',
#  'varem',
#  'valge',
#  'juurde',
#  'isa',
#  'maailm',
#  'koos',
#  'n.',
#  'rahulik',
#  'ülemnõukogu',
#  'ületama',
#  'edukas',
#  'õppima',
#  'kommunism',
#  'tööstus',
#  'puudus',
#  'vabadus',
#  'niisugune',
#  'väga',
#  'j.',
#  'otsustama',
#  'ungari',
#  'loomine',
#  'instituut',
#  'maja',
#  'lõpetama',
#  'valima',
#  'kuni',
#  'kuulama',
#  'parem',
#  'võit',
#  'näide',
#  'suutma',
#  'avaldama',
#  'arvama',
#  'vastama',
#  'vajalik',
#  'kuuluma',
#  'kindel',
#  'õpilane',
#  'aken',
#  'seal',
#  'õige',
#  'rääkima',
#  'tähtsam',
#  'juhtima',
#  'vaja',
#  'leidma',
#  'uuesti',
#  'järgi',
#  'asemel',
#  'edasine',
#  'põllumajanduslik',
#  'vahel',
#  'suurenema',
#  'korea',
#  'ettepanek',
#  'ligi',
#  'täitevkomitee',
#  'masin',
#  'selge',
#  'kandma',
#  'lõpp',
#  'möödunud',
#  'kuulma',
#  'pea',
#  'valija',
#  'kontroll',
#  'teade',
#  'vili',
#  'viima',
#  'üles',
#  'vene',
#  'ametiühing',
#  'laps',
#  'punkt',
#  'delegaat',
#  'prantsuse',
#  'pleenum',
#  'noorsugu',
#  'grupp',
#  'asi',
#  'osakond',
#  'alustama',
#  'homme',
#  'jutt',
#  'milline',
#  'teos',
#  'kõnelema',
#  'karl',
#  'ju',
#  'arendamine',
#  'taotlema',
#  'tõsine',
#  'veelgi',
#  'võim',
#  'protsent',
#  'üldine',
#  'kasutamine',
#  'kolmas',
#  'kava',
#  'sisse',
#  'käik',
#  'kodumaa',
#  'kultuur',
#  'vaenlane',
#  'võitleja',
#  'rahvaarmee',
#  'sektor',
#  'tartu',
#  'näitus',
#  'ettevalmistamine',
#  'oblast',
#  'akadeemia',
#  'traktor',
#  'kusjuures',
#  'hästi',
#  'jutustama',
#  'jaanuar',
#  'kujunema',
#  'bolševik',
#  'algama',
#  'maha',
#  'kohus',
#  'hääl',
#  'saadik',
#  'antud',
#  'arutama',
#  'kaasa',
#  'ha',
#  'vestlus',
#  'kuus',
#  'parteiorganisatsioon',
#  'vähemalt',
#  'ek',
#  'revolutsiooniline',
#  'artikkel',
#  'muidugi',
#  'rõõm',
#  'otse',
#  'edu',
#  'teadmine',
#  'arenema',
#  'majanduslik',
#  'viis',
#  'must',
#  'tase',
#  'kaader',
#  'rahvuslik',
#  'tšehhoslovakkia',
#  'ühtsus',
#  'pühendama',
#  'asetäitja',
#  'york',
#  'koosolek',
#  'andmine',
#  'osas',
#  'piim',
#  'jne',
#  'maakond',
#  'komisjon',
#  'igasugune',
#  'ajakirjandus',
#  'kodanik',
#  'võitma',
#  'nr',
#  'tänavu',
#  'tugev',
#  'siiski',
#  'seotud',
#  'lugu',
#  'vesi',
#  'peaaegu',
#  'kokku',
#  'lubama',
#  'jõudma',
#  'dünamo',
#  'vana',
#  'kollektiiv',
#  'viibima',
#  'mets',
#  'ent',
#  'vanem',
#  'tagajärg',
#  'suhtes',
#  'teostama',
#  'tanja',
#  'nägu',
#  'teadus',
#  'tööstusettevõte',
#  'kinnitama',
#  'sõjajärgne',
#  'töölisklass',
#  'saavutus',
#  'lööma',
#  'eesmärk',
#  'ajalugu',
#  'areng',
#  'periood',
#  'tooma',
#  'arvestama',
#  'ajal',
#  'abinõu',
#  'tähtsus',
#  'inglise',
#  'kokkulepe',
#  'ilma',
#  'talupoeg',
#  'lipp',
#  'eile',
#  'laud',
#  'keskkomitee',
#  'lammas',
#  'tehas',
#  'suurem',
#  'külv',
#  'm.',
#  'nõupidamine',
#  'selgitama',
#  'keegi',
#  'just',
#  'kiri',
#  'arutamine',
#  'muu',
#  'inglis',
#  'nõudmine',
#  'pilk',
#  'all',
#  'ensv',
#  'kunagi',
#  'sügis',
#  'tarvis',
#  'tõusma',
#  'täiesti',
#  'mõtlema',
#  'mäng',
#  'selline',
#  'tekkima',
#  'kaup',
#  'hoidma',
#  'artell',
#  'säärane',
#  'poole',
#  'sündmus',
#  'võrra',
#  'vastavalt',
#  'kasvama',
#  'kümme',
#  'varustama',
#  'ikka',
#  'tõeline',
#  'bolševistlik',
#  'pidevalt',
#  'süsteem',
#  'soov',
#  'rahvusvaheline',
#  'sellepärast',
#  'siga',
#  'juhtiv',
#  'saadud',
#  'v',
#  'eriline',
#  'nõue',
#  'lenin',
#  'jaoks',
#  'lahendama',
#  'vaba',
#  'põhikiri',
#  'halb',
#  'valmis',
#  'ühtlasi',
#  'h.',
#  'meister',
#  'mõte',
#  'õhk',
#  'istung',
#  'nimel',
#  'autor',
#  'vastav',
#  'punane',
#  'õhtu',
#  'seepärast',
#  'pakkuma',
#  'sein',
#  'seinaleht',
#  'august',
#  'hiljem',
#  'raamatukogu',
#  'põrsas',
#  's.',
#  'seni',
#  'käitis',
#  'lihtne',
#  'tõmbama',
#  'lühike',
#  'üldkoosolek',
#  'komsomol',
#  'omama',
#  'stahhaanovlane',
#  'hooaeg',
#  'london',
#  'tunduma',
#  'kokkuhoid',
#  'hektaar',
#  'kohe',
#  'elanik',
#  'ema',
#  'vedama',
#  'üleliiduline',
#  'kommunist',
#  'peremees',
#  'majand',
#  'palestiina',
#  'metsatöö',
#  'batmanov',
#  'määrus',
#  'õpetaja',
#  'toime',
#  'kindlustamine',
#  'ühiskond',
#  'talurahvas',
#  'leningrad',
#  'ühiskondlik',
#  'määrama',
#  'kasv',
#  'seadma',
#  'seega',
#  'ii',
#  'rumeenia',
#  'alus',
#  'nev',
#  'võitlema',
#  'taga',
#  'direktor',
#  'jt',
#  'euroopa',
#  'au',
#  'tuhat',
#  'loom',
#  'krai',
#  'organiseerimine',
#  'olev',
#  'peamine',
#  'ehitusmaterjal',
#  'tähtaeg',
#  'ehitamine',
#  'abistama',
#  'moodustama',
#  'hobune',
#  'hiljuti',
#  'siit',
#  'miks',
#  'maksma',
#  'algul',
#  'eeskuju',
#  'fakt',
#  'liikumine',
#  'katkestama',
#  'sundima',
#  'kreeka',
#  'viga',
#  'selguma',
#  'kodanlik',
#  'rühm',
#  'mängima',
#  'partii',
#  'oskama',
#  'hommik',
#  'kartul',
#  'kõigepealt',
#  'loeng',
#  'e.',
#  'abi',
#  'venemaa',
#  'suurepärane',
#  'tegelema',
#  'kg',
#  'täis',
#  'ühiselamu',
#  'kongress',
#  'auto',
#  'i.',
#  'tervitama',
#  'kirjutama',
#  'vastuvõtmine',
#  'nimetama',
#  'nädal',
#  'jälle',
#  'õieti',
#  'lükkama',
#  'hoolitsema',
#  'unustama',
#  'julgeolekunõukogu',
#  'hääletama',
#  'teema',
#  'trust',
#  'hing',
#  'eel',
#  'kodu',
#  'kuigi',
#  'sinna',
#  'otsima',
#  'aleksei',
#  'noh',
#  'vahetus',
#  'kiiduavaldus',
#  'toodang',
#  'viisaastak',
#  'jätkuma',
#  'ümber',
#  'võimaldama',
#  'tohtima',
#  'kogemus',
#  'kõrgem',
#  'teaduslik',
#  'ehitus',
#  'varustamine',
#  'probleem',
#  'tõstma',
#  'parandama',
#  'määratud',
#  'suunatud',
#  'jaapan',
#  'põhiline',
#  'fašistlik',
#  'september',
#  'esile',
#  'jalg',
#  'prof',
#  'kõne',
#  'stahhaanovlik',
#  'parandamine',
#  'ettenähtud',
#  'juuli',
#  'toiduaine',
#  'lehm',
#  'kasvatama',
#  'organ',
#  'kursus',
#  'määr',
#  'järel',
#  'ruum',
#  'pikk',
#  'puudutama',
#  'rakendamine',
#  'kritiseerima',
#  'elav',
#  'saar',
#  'tunnistama',
#  'selg',
#  'agitaator',
#  'stalinlik',
#  'kirjasaatja',
#  'vaatamata',
#  'kuulaja',
#  'ringi',
#  'viivitamatult',
#  'kokkuvõte',
#  'järgnema',
#  'terve',
#  'kehakultuur',
#  'selgitustöö',
#  'tungima',
#  'kirjandus',
#  'suurim',
#  'sõber',
#  'aus',
#  'kuhu',
#  'avama',
#  'komitee',
#  'kirjanik',
#  'koit',
#  'kestma',
#  'käes',
#  'läbirääkimine',
#  'järjekordne',
#  'tõhus',
#  'mure',
#  'hetk',
#  'noorsooühing',
#  'asutis',
#  'süvenema',
#  'nimeline',
#  'm',
#  'vabariiklik',
#  'lugeja',
#  'tähtis',
#  'uskuma',
#  'tund',
#  'berliin',
#  'lai',
#  'asetama',
#  'moldaavia',
#  'jüri',
#  'teatav',
#  'karotamm',
#  'sild',
#  'mingisugune',
#  'kohustuslik',
#  'märkama',
#  'vaevalt',
#  'objekt',
#  'kombinaat',
#  'kerge',
#  'jaak',
#  'pöörama',
#  'tunduv',
#  'armastatud',
#  'armee',
#  'suurendama',
#  'sõjalaevastik',
#  'ühendama',
#  'armastama',
#  'teostamine',
#  'taastama',
#  'tootmine',
#  'valmistama',
#  'võrdlema',
#  'tööviljakus',
#  'kauplus',
#  'tehnika',
#  'kasvatus',
#  'hiina',
#  'õigus',
#  'inglismaa',
#  'ülikool',
#  'saatel',
#  'november',
#  'tekst',
#  'kvartal',
#  'lind',
#  'tõttu',
#  'rakendama',
#  'kasvatamine',
#  'kilomeeter',
#  'täielik',
#  'hooldamine',
#  'tarbija',
#  'suund',
#  'sööt',
#  'traktorist',
#  'laev',
#  'ettekanne',
#  'konkreetne',
#  'ühine',
#  'istungjärk',
#  'toimetama',
#  'kontrollimine',
#  'vastus',
#  'märts',
#  'leiduma',
#  'k.',
#  'mitmesugune',
#  'pariis',
#  'e',
#  'heitma',
#  'kaudu',
#  'kaotus',
#  'kehtestama',
#  'nimekiri',
#  'nimi',
#  'läbiviimine',
#  'agentuur',
#  'vähem',
#  'käsitlema',
#  'algus',
#  'ühendus',
#  'ehitustrust',
#  'täpselt',
#  'lõppema',
#  'juhatus',
#  'sageli',
#  'hoog',
#  'lähem',
#  'h',
#  'võimalik',
#  'kiiresti',
#  'kindlasti',
#  'kehakultuurikollektiiv',
#  'arenemine',
#  'tasuma',
#  'töödistsipliin',
#  'kriitika',
#  'ilm',
#  'toetama',
#  'vähe',
#  'idee',
#  'side',
#  'rajama',
#  'paljastama',
#  'lk',
#  'progressiivne',
#  'ilmuma',
#  'lõpuks',
#  'kõrval',
#  'tõnu',
#  'üritus',
#  'minut',
#  'paar',
#  'sort',
#  'film',
#  'tihe',
#  'ülem',
#  'äratama',
#  'saamine',
#  'võrumaa',
#  'ametnik',
#  'itaalia',
#  'naine',
#  'delegatsioon',
#  'peaassamblee',
#  'juhtuma',
#  'harjumaa',
#  'aastaplaan',
#  'ülesehitamine',
#  'asuv',
#  'siia',
#  'asutav',
#  'laiali',
#  'g.',
#  'kartma',
#  'naeratama',
#  'seadlus',
#  'teeneline',
#  'päike',
#  'pioneerilaager',
#  'lumi',
#  'klass',
#  'meetod',
#  'mööda',
#  'rukis',
#  'vend',
#  'kuju',
#  'istuma',
#  'talu',
#  'vaikima',
#  'valimiskomisjon',
#  'beridze',
#  'sotsialism',
#  'arendama',
#  'asutus',
#  'säästma',
#  'tark',
#  'edusamm',
#  'imperialist',
#  'valla',
#  'veenduma',
#  'eesrindlane',
#  'poliitika',
#  'ülesehitustöö',
#  'lootma',
#  'aktiivsus',
#  'materjal',
#  'elektrienergia',
#  'vastuvõetud',
#  'kerkima',
#  'suurenemine',
#  'relvastatud',
#  'kujutama',
#  'keskmine',
#  'kapitalism',
#  'nähtus',
#  'koostöö',
#  'avalik',
#  'raskus',
#  'toimuv',
#  'massiline',
#  'aru',
#  'juuni',
#  'armastus',
#  'tulevik',
#  'prantsusmaa',
#  'lisama',
#  'tähistama',
#  'paul',
#  'kultuurimaja',
#  'repertuaar',
#  'farm',
#  'veis',
#  'talv',
#  'praktiline',
#  'hulgast',
#  'tänu',
#  'tutvuma',
#  'leping',
#  'tootmisplaan',
#  'põhjus',
#  'paluma',
#  'üliõpilane',
#  'töönorm',
#  'kevadkülv',
#  'keskel',
#  'õigeaegselt',
#  'turbatööstus',
#  'üksi',
#  'arst',
#  'isik',
#  'valmistuma',
#  'kontsert',
#  'haigla',
#  'hüüdma',
#  'koosseis',
#  'hääletamine',
#  'turg',
#  'esindus',
#  'huvitav',
#  'osavõtt',
#  'sõnavõtt',
#  'otsekohe',
#  'tehtud',
#  'esialgu',
#  'viidud',
#  'normipäev',
#  'valik',
#  'saak',
#  'praegune',
#  'õigesti',
#  'k',
#  'l.',
#  'muuseum',
#  'luuletaja',
#  'teenima',
#  'kaugel',
#  'kõrge',
#  'töörahvas',
#  'sündima',
#  'vihm',
#  'kõrgus',
#  'õnnestuma',
#  'kultuuriline',
#  'sammuma',
#  'resolutsioon',
#  'vahend',
#  ...]

# %%
for decade, svd_model in svd_models.items():
    print(decade)
    #svd_model = svd2vec.load(f"{MODEL_DIR}/{file}")
    svd_model.save_word2vec_format(f"{MODEL_DIR}/diff_svd_{decade}.model")
# Out:
# 1900
# 1910

# %% [markdown]
# ### Reading in SVD vectors as word2vec format (could not use this)

# %%
from gensim.models import KeyedVectors

svd_models = {}

MODEL_DIR = "./models/svd"
all_files = [f for f in listdir(MODEL_DIR) if isfile(join(MODEL_DIR, f))]
all_files = [filename for filename in all_files if filename[-5:] == "model" and filename[-4:] not in [".zip", "r.gz"] and "aligned" not in filename and "diff" in filename]

for file in all_files:
    print(file)
    svd_model = KeyedVectors.load_word2vec_format(f"{MODEL_DIR}/{file}", binary=False, encoding= 'unicode_escape')
    svd_models[int(file[9:13])] = svd_model
# Out:
# diff_svd_1900.model
# diff_svd_1910.model

# %% [markdown]
# # Aligning vectors
#
# ## Aligning word2vec

# %%
MODEL_DIR = "./models/word2vec"

# %%
models
# Out:
# {1890: <gensim.models.word2vec.Word2Vec at 0x11e608abdf0>,
#  1900: <gensim.models.word2vec.Word2Vec at 0x11e2150c4f0>,
#  1910: <gensim.models.word2vec.Word2Vec at 0x11e581e9250>,
#  1930: <gensim.models.word2vec.Word2Vec at 0x11e581e98b0>,
#  1950: <gensim.models.word2vec.Word2Vec at 0x11e581e91c0>,
#  1960: <gensim.models.word2vec.Word2Vec at 0x11e581e9070>,
#  1970: <gensim.models.word2vec.Word2Vec at 0x11e21d0bfd0>,
#  1980: <gensim.models.word2vec.Word2Vec at 0x11e21d0b640>,
#  1990: <gensim.models.word2vec.Word2Vec at 0x11e21d0b5b0>}

# %%
decades = list(models.keys())
print(decades)
# Out:
# [1890, 1900, 1910, 1930, 1950, 1960, 1970, 1980, 1990]

# %%
# Code from https://gist.github.com/zhicongchen/9e23d5c3f1e5b1293b16133485cd17d8

def smart_procrustes_align_gensim(base_embed, other_embed, words=None):
    """
    Original script: https://gist.github.com/quadrismegistus/09a93e219a6ffc4f216fb85235535faf
    Procrustes align two gensim word2vec models (to allow for comparison between same word across models).
    Code ported from HistWords <https://github.com/williamleif/histwords> by William Hamilton <wleif@stanford.edu>.
        
    First, intersect the vocabularies (see `intersection_align_gensim` documentation).
    Then do the alignment on the other_embed model.
    Replace the other_embed model's syn0 and syn0norm numpy matrices with the aligned version.
    Return other_embed.

    If `words` is set, intersect the two models' vocabulary with the vocabulary in words (see `intersection_align_gensim` documentation).
    """

    # patch by Richard So [https://twitter.com/richardjeanso) (thanks!) to update this code for new version of gensim
    # base_embed.init_sims(replace=True)
    # other_embed.init_sims(replace=True)

    # make sure vocabulary and indices are aligned
    in_base_embed, in_other_embed = intersection_align_gensim(base_embed, other_embed, words=words)

    # get the (normalized) embedding matrices
    base_vecs = in_base_embed.wv.get_normed_vectors()
    other_vecs = in_other_embed.wv.get_normed_vectors()

    # just a matrix dot product with numpy
    m = other_vecs.T.dot(base_vecs) 
    # SVD method from numpy
    u, _, v = np.linalg.svd(m)
    # another matrix operation
    ortho = u.dot(v) 
    # Replace original array with modified one, i.e. multiplying the embedding matrix by "ortho"
    other_embed.wv.vectors = (other_embed.wv.vectors).dot(ortho)    
    
    return other_embed

def intersection_align_gensim(m1, m2, words=None):
    """
    Intersect two gensim word2vec models, m1 and m2.
    Only the shared vocabulary between them is kept.
    If 'words' is set (as list or set), then the vocabulary is intersected with this list as well.
    Indices are re-organized from 0..N in order of descending frequency (=sum of counts from both m1 and m2).
    These indices correspond to the new syn0 and syn0norm objects in both gensim models:
        -- so that Row 0 of m1.syn0 will be for the same word as Row 0 of m2.syn0
        -- you can find the index of any word on the .index2word list: model.index2word.index(word) => 2
    The .vocab dictionary is also updated for each model, preserving the count but updating the index.
    """

    # Get the vocab for each model
    vocab_m1 = set(m1.wv.index_to_key)
    vocab_m2 = set(m2.wv.index_to_key)

    # Find the common vocabulary
    common_vocab = vocab_m1 & vocab_m2
    if words: common_vocab &= set(words)

    # If no alignment necessary because vocab is identical...
    if not vocab_m1 - common_vocab and not vocab_m2 - common_vocab:
        return (m1,m2)

    # Otherwise sort by frequency (summed for both)
    common_vocab = list(common_vocab)
    common_vocab.sort(key=lambda w: m1.wv.get_vecattr(w, "count") + m2.wv.get_vecattr(w, "count"), reverse=True)
    # print(len(common_vocab))

    # Then for each model...
    for m in [m1, m2]:
        # Replace old syn0norm array with new one (with common vocab)
        indices = [m.wv.key_to_index[w] for w in common_vocab]
        old_arr = m.wv.vectors
        new_arr = np.array([old_arr[index] for index in indices])
        m.wv.vectors = new_arr

        # Replace old vocab dictionary with new one (with common vocab)
        # and old index2word with new one
        new_key_to_index = {}
        new_index_to_key = []
        for new_index, key in enumerate(common_vocab):
            new_key_to_index[key] = new_index
            new_index_to_key.append(key)
        m.wv.key_to_index = new_key_to_index
        m.wv.index_to_key = new_index_to_key
        
        print(len(m.wv.key_to_index), len(m.wv.vectors))
        
    return (m1,m2)

# %%
#Set the start and end indexes
start = 1890
end = 1990

start_ind = decades.index(start)
end_ind = decades.index(end)

# %%
aligned_models = {}

for i in range(start_ind, end_ind):
    #print(decades[i], decades[i+1])
    # FIX from https://gist.github.com/zhicongchen/9e23d5c3f1e5b1293b16133485cd17d8?permalink_comment_id=3837234#gistcomment-3837234
    base_embed = models[decades[i]]
    other_embed = models[decades[i+1]]
    
    # make sure vocabulary and indices are aligned
    in_base_embed, in_other_embed = intersection_align_gensim(base_embed, other_embed)

    # re-filling the normed vectors
    in_base_embed.wv.fill_norms(force=True)
    in_other_embed.wv.fill_norms(force=True)

    # get the (normalized) embedding matrices
    base_vecs = in_base_embed.wv.get_normed_vectors()
    other_vecs = in_other_embed.wv.get_normed_vectors()
    
    # we can do this because time point t's in_other_embed equals t+1's in_base_embed
    aligned_models[decades[i]] = in_base_embed
    aligned_models[decades[i+1]] = in_other_embed
    
for decade, model in aligned_models.items():
    model.save(f"{MODEL_DIR}/word2vec_{start}-{end}_{decade}_aligned.model")
# Out:
# 2402 2402
# 2402 2402
# 2087 2087
# 2087 2087
# 1728 1728
# 1728 1728
# 1321 1321
# 1321 1321
# 1252 1252
# 1252 1252
# 1233 1233
# 1233 1233
# 1233 1233
# 1233 1233
# 1232 1232
# 1232 1232

# %% [markdown]
# ## Aligning SVD models

# %%
MODEL_DIR = "./models/svd"

# %%
svd_models
# Out:
# {1890: <svd2vec.core.svd2vec at 0x11e58d86b20>,
#  1900: <svd2vec.core.svd2vec at 0x11e58d86340>,
#  1910: <svd2vec.core.svd2vec at 0x11e58d867f0>,
#  1930: <svd2vec.core.svd2vec at 0x11e58d869d0>,
#  1950: <svd2vec.core.svd2vec at 0x11e58d86af0>,
#  1960: <svd2vec.core.svd2vec at 0x11e58d86460>,
#  1970: <svd2vec.core.svd2vec at 0x11e58d86580>,
#  1980: <svd2vec.core.svd2vec at 0x11e58d86430>,
#  1990: <svd2vec.core.svd2vec at 0x11e58d86ca0>}

# %%
"""
# Code from https://gist.github.com/zhicongchen/9e23d5c3f1e5b1293b16133485cd17d8

def smart_procrustes_align_gensim(base_embed, other_embed, words=None):
    
    Original script: https://gist.github.com/quadrismegistus/09a93e219a6ffc4f216fb85235535faf
    Procrustes align two gensim word2vec models (to allow for comparison between same word across models).
    Code ported from HistWords <https://github.com/williamleif/histwords> by William Hamilton <wleif@stanford.edu>.
        
    First, intersect the vocabularies (see `intersection_align_gensim` documentation).
    Then do the alignment on the other_embed model.
    Replace the other_embed model's syn0 and syn0norm numpy matrices with the aligned version.
    Return other_embed.

    If `words` is set, intersect the two models' vocabulary with the vocabulary in words (see `intersection_align_gensim` documentation).
    

    # patch by Richard So [https://twitter.com/richardjeanso) (thanks!) to update this code for new version of gensim
    # base_embed.init_sims(replace=True)
    # other_embed.init_sims(replace=True)

    # make sure vocabulary and indices are aligned
    in_base_embed, in_other_embed = intersection_align_gensim(base_embed, other_embed, words=words)

    # get the (normalized) embedding matrices
    base_vecs = in_base_embed.wv.get_normed_vectors()
    other_vecs = in_other_embed.wv.get_normed_vectors()

    # just a matrix dot product with numpy
    m = other_vecs.T.dot(base_vecs) 
    # SVD method from numpy
    u, _, v = np.linalg.svd(m)
    # another matrix operation
    ortho = u.dot(v) 
    # Replace original array with modified one, i.e. multiplying the embedding matrix by "ortho"
    other_embed.wv.vectors = (other_embed.wv.vectors).dot(ortho)    
    
    return other_embed

def intersection_align_gensim(m1, m2, words=None):
    
    Intersect two gensim word2vec models, m1 and m2.
    Only the shared vocabulary between them is kept.
    If 'words' is set (as list or set), then the vocabulary is intersected with this list as well.
    Indices are re-organized from 0..N in order of descending frequency (=sum of counts from both m1 and m2).
    These indices correspond to the new syn0 and syn0norm objects in both gensim models:
        -- so that Row 0 of m1.syn0 will be for the same word as Row 0 of m2.syn0
        -- you can find the index of any word on the .index2word list: model.index2word.index(word) => 2
    The .vocab dictionary is also updated for each model, preserving the count but updating the index.
    

    # Get the vocab for each model
    vocab_m1 = set(m1.wv.index_to_key)
    vocab_m2 = set(m2.wv.index_to_key)

    # Find the common vocabulary
    common_vocab = vocab_m1 & vocab_m2
    if words: common_vocab &= set(words)

    # If no alignment necessary because vocab is identical...
    if not vocab_m1 - common_vocab and not vocab_m2 - common_vocab:
        return (m1,m2)

    # Otherwise sort by frequency (summed for both)
    common_vocab = list(common_vocab)
    common_vocab.sort(key=lambda w: m1.wv.get_vecattr(w, "count") + m2.wv.get_vecattr(w, "count"), reverse=True)
    # print(len(common_vocab))

    # Then for each model...
    for m in [m1, m2]:
        # Replace old syn0norm array with new one (with common vocab)
        indices = [m.wv.key_to_index[w] for w in common_vocab]
        old_arr = m.wv.vectors
        new_arr = np.array([old_arr[index] for index in indices])
        m.wv.vectors = new_arr

        # Replace old vocab dictionary with new one (with common vocab)
        # and old index2word with new one
        new_key_to_index = {}
        new_index_to_key = []
        for new_index, key in enumerate(common_vocab):
            new_key_to_index[key] = new_index
            new_index_to_key.append(key)
        m.wv.key_to_index = new_key_to_index
        m.wv.index_to_key = new_index_to_key
        
        print(len(m.wv.key_to_index), len(m.wv.vectors))
        
    return (m1,m2)
"""

def intersection_align_svd(m1, m2, words=None):
    """
    Intersect two gensim word2vec models, m1 and m2.
    Only the shared vocabulary between them is kept.
    If 'words' is set (as list or set), then the vocabulary is intersected with this list as well.
    Indices are re-organized from 0..N in order of descending frequency (=sum of counts from both m1 and m2).
    These indices correspond to the new syn0 and syn0norm objects in both gensim models:
        -- so that Row 0 of m1.syn0 will be for the same word as Row 0 of m2.syn0
        -- you can find the index of any word on the .index2word list: model.index2word.index(word) => 2
    The .vocab dictionary is also updated for each model, preserving the count but updating the index.
    """

    # Get the vocab for each model
    vocab_m1 = set(m1.words)
    vocab_m2 = set(m2.words)

    # Find the common vocabulary
    common_vocab = vocab_m1 & vocab_m2
    if words: common_vocab &= set(words)

    # If no alignment necessary because vocab is identical...
    if not vocab_m1 - common_vocab and not vocab_m2 - common_vocab:
        return (m1,m2)

    # Otherwise sort by frequency (summed for both)
    common_vocab = list(common_vocab)
    common_vocab.sort(key=lambda w: m1.terms_counts[w] + m2.terms_counts[w], reverse=True)
    # print(len(common_vocab))

    # Then for each model...
    for m in [m1, m2]:
        # Replace old syn0norm array with new one (with common vocab)
        indices = [m.vocabulary[w] for w in common_vocab]
        old_arr = m.svd_w
        new_arr = np.array([old_arr[index] for index in indices])
        m.svd_w = new_arr

        # Replace old vocab dictionary with new one (with common vocab)
        # and old index2word with new one
        new_key_to_index = {}
        new_index_to_key = []
        for new_index, key in enumerate(common_vocab):
            new_key_to_index[key] = new_index
            new_index_to_key.append(key)
        m.vocabulary = new_key_to_index
        m.words = new_index_to_key
        
        print(len(m.vocabulary), len(m.svd_w))
        
    return (m1,m2)

# %%
#Set the start and end indexes
start = 1890
end = 1990

start_ind = decades.index(start)
end_ind = decades.index(end)

# %%
aligned_svd_models = {}

for i in range(start_ind, end_ind):
    # FIX from https://gist.github.com/zhicongchen/9e23d5c3f1e5b1293b16133485cd17d8?permalink_comment_id=3837234#gistcomment-3837234
    base_embed = svd_models[decades[i]]
    other_embed = svd_models[decades[i+1]]
    
    # make sure vocabulary and indices are aligned
    in_base_embed, in_other_embed = intersection_align_svd(base_embed, other_embed)

    # re-filling the normed vectors
    #in_base_embed.wv.fill_norms(force=True)
    #in_other_embed.wv.fill_norms(force=True)

    # get the (normalized) embedding matrices
    #base_vecs = in_base_embed.wv.get_normed_vectors()
    #other_vecs = in_other_embed.wv.get_normed_vectors()
    
    # we can do this because time point t's in_other_embed equals t+1's in_base_embed
    aligned_svd_models[decades[i]] = in_base_embed
    aligned_svd_models[decades[i+1]] = in_other_embed
    
for decade, model in aligned_svd_models.items():
    model.save(f"{MODEL_DIR}/svd_{start}-{end}_{decade}_aligned.model")
# Out:
# 3795 3795
# 3795 3795
# 3187 3187
# 3187 3187
# 2589 2589
# 2589 2589
# 1977 1977
# 1977 1977
# 1884 1884
# 1884 1884
# 1849 1849
# 1849 1849
# 1846 1846
# 1846 1846
# 1844 1844
# 1844 1844

# %%
aligned_svd_models
# Out:
# {1890: <svd2vec.core.svd2vec at 0x11e58d86b20>,
#  1900: <svd2vec.core.svd2vec at 0x11e58d86340>,
#  1910: <svd2vec.core.svd2vec at 0x11e58d867f0>,
#  1930: <svd2vec.core.svd2vec at 0x11e58d869d0>,
#  1950: <svd2vec.core.svd2vec at 0x11e58d86af0>,
#  1960: <svd2vec.core.svd2vec at 0x11e58d86460>,
#  1970: <svd2vec.core.svd2vec at 0x11e58d86580>,
#  1980: <svd2vec.core.svd2vec at 0x11e58d86430>,
#  1990: <svd2vec.core.svd2vec at 0x11e58d86ca0>}

# %% [markdown]
# ## Saving diachronic embeddings
#
# ### word2vec

# %%
ref_year = 1990
all_words = list(aligned_models[ref_year].wv.key_to_index.keys())

# %%
keys = aligned_models[ref_year].wv.key_to_index
idxs = aligned_models[ref_year].wv.index_to_key

# %%
keys
# Out:
# {'olema': 0,
#  'ja': 1,
#  'tema': 2,
#  'see': 3,
#  'mina': 4,
#  'ei': 5,
#  'et': 6,
#  'mis': 7,
#  'kui': 8,
#  'ka': 9,
#  'oma': 10,
#  'aga': 11,
#  'saama': 12,
#  'sina': 13,
#  'ning': 14,
#  'siis': 15,
#  'kes': 16,
#  'või': 17,
#  'tulema': 18,
#  'ise': 19,
#  'pidama': 20,
#  'aasta': 21,
#  'üks': 22,
#  'nii': 23,
#  'kõik': 24,
#  'võima': 25,
#  'tegema': 26,
#  'teine': 27,
#  'nagu': 28,
#  'minema': 29,
#  'ütlema': 30,
#  'eesti': 31,
#  'veel': 32,
#  'aeg': 33,
#  'jääma': 34,
#  'võtma': 35,
#  'juba': 36,
#  'mees': 37,
#  'inimene': 38,
#  'kuid': 39,
#  'hakkama': 40,
#  'teadma': 41,
#  'kas': 42,
#  'suur': 43,
#  'miski': 44,
#  'välja': 45,
#  'ära': 46,
#  'nägema': 47,
#  'nüüd': 48,
#  'andma': 49,
#  'üle': 50,
#  'tahtma': 51,
#  'mitte': 52,
#  'palju': 53,
#  'mõni': 54,
#  'töö': 55,
#  'vaid': 56,
#  'ainult': 57,
#  'kord': 58,
#  'uus': 59,
#  'küll': 60,
#  'vastu': 61,
#  'kus': 62,
#  'pärast': 63,
#  'kaks': 64,
#  'sest': 65,
#  'naine': 66,
#  'vaatama': 67,
#  'käsi': 68,
#  'enam': 69,
#  'esimene': 70,
#  'iga': 71,
#  'panema': 72,
#  'päev': 73,
#  'eest': 74,
#  'ju': 75,
#  'siin': 76,
#  'peale': 77,
#  'ega': 78,
#  'rääkima': 79,
#  'asi': 80,
#  'keegi': 81,
#  'mõtlema': 82,
#  'tundma': 83,
#  'käima': 84,
#  'kuidas': 85,
#  'väga': 86,
#  'silm': 87,
#  'jõudma': 88,
#  'elu': 89,
#  'tagasi': 90,
#  'hea': 91,
#  'sõna': 92,
#  'seal': 93,
#  'kõige': 94,
#  'läbi': 95,
#  'laps': 96,
#  'ikka': 97,
#  'kogu': 98,
#  'viimane': 99,
#  'mingi': 100,
#  'leidma': 101,
#  'maa': 102,
#  'arvama': 103,
#  'tallinn': 104,
#  'ette': 105,
#  'osa': 106,
#  'rohkem': 107,
#  'pea': 108,
#  'seisma': 109,
#  'isegi': 110,
#  'praegu': 111,
#  'riik': 112,
#  'linn': 113,
#  'alla': 114,
#  'sama': 115,
#  'küsima': 116,
#  'tooma': 117,
#  'just': 118,
#  'mitu': 119,
#  'elama': 120,
#  'enne': 121,
#  'mõte': 122,
#  'pool': 123,
#  'vahel': 124,
#  'ema': 125,
#  'muu': 126,
#  'poole': 127,
#  'vana': 128,
#  'väike': 129,
#  'kolm': 130,
#  'noor': 131,
#  'kohta': 132,
#  'tee': 133,
#  'all': 134,
#  'ees': 135,
#  'kodu': 136,
#  'rahvas': 137,
#  'istuma': 138,
#  'juurde': 139,
#  'jätma': 140,
#  'koht': 141,
#  'ootama': 142,
#  'maja': 143,
#  'juht': 144,
#  'viima': 145,
#  'koos': 146,
#  'kirjutama': 147,
#  'a': 148,
#  'siiski': 149,
#  'edasi': 150,
#  'maailm': 151,
#  'kokku': 152,
#  'poolt': 153,
#  'püüdma': 154,
#  'laskma': 155,
#  'miks': 156,
#  'kuni': 157,
#  'isa': 158,
#  'kuulma': 159,
#  'jälle': 160,
#  'alles': 161,
#  'poiss': 162,
#  'muutuma': 163,
#  'suutma': 164,
#  'astuma': 165,
#  'sõitma': 166,
#  'nägu': 167,
#  'tartu': 168,
#  'kohe': 169,
#  'küsimus': 170,
#  'muidugi': 171,
#  'lugema': 172,
#  'keel': 173,
#  'uks': 174,
#  'suurem': 175,
#  'pikk': 176,
#  'üles': 177,
#  'sisse': 178,
#  'ehk': 179,
#  'maha': 180,
#  'vastama': 181,
#  'lõpp': 182,
#  'niisugune': 183,
#  'kuigi': 184,
#  'alati': 185,
#  'näitama': 186,
#  'hoidma': 187,
#  'jalg': 188,
#  'vesi': 189,
#  'juures': 190,
#  'raha': 191,
#  'tüdruk': 192,
#  'oskama': 193,
#  'jutt': 194,
#  'nimi': 195,
#  'ümber': 196,
#  'parem': 197,
#  'valge': 198,
#  'vaja': 199,
#  'valitsus': 200,
#  'tõusma': 201,
#  'kunagi': 202,
#  'võimalik': 203,
#  'hästi': 204,
#  'raamat': 205,
#  'ometi': 206,
#  'kinni': 207,
#  'hiljem': 208,
#  'õige': 209,
#  'hääl': 210,
#  'lahti': 211,
#  'tekkima': 212,
#  'laud': 213,
#  'järgmine': 214,
#  'kaasa': 215,
#  'täis': 216,
#  'ajama': 217,
#  'meel': 218,
#  'raske': 219,
#  'mööda': 220,
#  'paar': 221,
#  'töötama': 222,
#  'pilk': 223,
#  'viis': 224,
#  'taga': 225,
#  'lööma': 226,
#  'mõistma': 227,
#  'tuba': 228,
#  'kuu': 229,
#  'aru': 230,
#  'jah': 231,
#  'saatma': 232,
#  'asuma': 233,
#  'järele': 234,
#  'aitama': 235,
#  'kutsuma': 236,
#  'kandma': 237,
#  'otsima': 238,
#  'mängima': 239,
#  'kool': 240,
#  'miljon': 241,
#  'tähendama': 242,
#  '': 243,
#  'õhtu': 244,
#  'kindel': 245,
#  'kasvama': 246,
#  'peaaegu': 247,
#  'kaduma': 248,
#  'tegevus': 249,
#  'õigus': 250,
#  'ilma': 251,
#  'nõudma': 252,
#  'lihtsalt': 253,
#  'maksma': 254,
#  'jaoks': 255,
#  'kell': 256,
#  'a.': 257,
#  'liiga': 258,
#  'juhtuma': 259,
#  'kiri': 260,
#  'sinna': 261,
#  'uskuma': 262,
#  'ülesanne': 263,
#  'paistma': 264,
#  'jõud': 265,
#  'hoopis': 266,
#  'selg': 267,
#  'jooksul': 268,
#  'tund': 269,
#  'kuuluma': 270,
#  'moskva': 271,
#  'lubama': 272,
#  'tõstma': 273,
#  'soome': 274,
#  'must': 275,
#  'vist': 276,
#  'nädal': 277,
#  'lugu': 278,
#  'terve': 279,
#  'täna': 280,
#  'varem': 281,
#  'ettevõte': 282,
#  'vabariik': 283,
#  'algus': 284,
#  'põhjus': 285,
#  'kinnitama': 286,
#  'päris': 287,
#  'kuhu': 288,
#  'mõlema': 289,
#  'otsus': 290,
#  'aken': 291,
#  'otsustama': 292,
#  'alus': 293,
#  'algama': 294,
#  'neli': 295,
#  'liige': 296,
#  'üsna': 297,
#  'endine': 298,
#  'tegemine': 299,
#  'tõmbama': 300,
#  'täitma': 301,
#  'vanem': 302,
#  'tohtima': 303,
#  'pakkuma': 304,
#  'meri': 305,
#  'märkama': 306,
#  'süda': 307,
#  'mets': 308,
#  'hommik': 309,
#  'selge': 310,
#  'võõras': 311,
#  'kuna': 312,
#  'täiesti': 313,
#  'õppima': 314,
#  'tõesti': 315,
#  'kõrval': 316,
#  'lõpetama': 317,
#  'vähemalt': 318,
#  'suu': 319,
#  'umbes': 320,
#  'looma': 321,
#  'tehtud': 322,
#  'nimetama': 323,
#  'seadus': 324,
#  'alustama': 325,
#  'lisama': 326,
#  'esimees': 327,
#  'puu': 328,
#  'mäng': 329,
#  'valima': 330,
#  'kartma': 331,
#  'teatama': 332,
#  'ilus': 333,
#  'liikuma': 334,
#  'samm': 335,
#  'tühi': 336,
#  'eks': 337,
#  'ajal': 338,
#  'kuulama': 339,
#  'kolmas': 340,
#  'paluma': 341,
#  'siia': 342,
#  'uuesti': 343,
#  'näima': 344,
#  'president': 345,
#  'nõnda': 346,
#  'lootma': 347,
#  'punane': 348,
#  'abi': 349,
#  'hing': 350,
#  'poeg': 351,
#  'veidi': 352,
#  'sõda': 353,
#  'pilt': 354,
#  'arv': 355,
#  'ilmuma': 356,
#  'langema': 357,
#  'valmis': 358,
#  'mäletama': 359,
#  'avama': 360,
#  'sõber': 361,
#  'kust': 362,
#  'kohalik': 363,
#  'vähem': 364,
#  'ostma': 365,
#  'sööma': 366,
#  'eesmärk': 367,
#  'leht': 368,
#  'tõttu': 369,
#  'kindlasti': 370,
#  'vähe': 371,
#  'sattuma': 372,
#  'ruum': 373,
#  'suvi': 374,
#  'kümme': 375,
#  'plaan': 376,
#  'kõrge': 377,
#  'sealt': 378,
#  'loom': 379,
#  'meeldima': 380,
#  'tähtis': 381,
#  'küla': 382,
#  'tunnistama': 383,
#  'kuidagi': 384,
#  'praegune': 385,
#  'sein': 386,
#  'jooksma': 387,
#  'avaldama': 388,
#  'peal': 389,
#  'tuhat': 390,
#  'võitma': 391,
#  'saksa': 392,
#  'soovima': 393,
#  'pöörama': 394,
#  'keskmine': 395,
#  'külm': 396,
#  'otsa': 397,
#  'öö': 398,
#  'vaba': 399,
#  'magama': 400,
#  'muutma': 401,
#  'sündima': 402,
#  'antud': 403,
#  'ajaleht': 404,
#  'olev': 405,
#  'ringi': 406,
#  'hulgas': 407,
#  'kohus': 408,
#  'surm': 409,
#  'naerma': 410,
#  'õpetaja': 411,
#  'kõrvale': 412,
#  'sellepärast': 413,
#  'uurima': 414,
#  'leping': 415,
#  'õhk': 416,
#  'vahele': 417,
#  'pisut': 418,
#  'kõnelema': 419,
#  'ehitama': 420,
#  'korral': 421,
#  'tegu': 422,
#  'tuttav': 423,
#  'hulk': 424,
#  'tugev': 425,
#  'piir': 426,
#  'kaotama': 427,
#  'seadma': 428,
#  'heitma': 429,
#  'tuul': 430,
#  'hind': 431,
#  'kaudu': 432,
#  'puuduma': 433,
#  'kevad': 434,
#  'seisukoht': 435,
#  'august': 436,
#  'keha': 437,
#  'otse': 438,
#  'seega': 439,
#  'vastus': 440,
#  'pääsema': 441,
#  'soe': 442,
#  'muidu': 443,
#  'm': 444,
#  'päike': 445,
#  'jne': 446,
#  'ala': 447,
#  'võit': 448,
#  'õlg': 449,
#  'puhas': 450,
#  'järel': 451,
#  'kivi': 452,
#  'rootsi': 453,
#  'direktor': 454,
#  'j.': 455,
#  'taevas': 456,
#  'lahkuma': 457,
#  'sundima': 458,
#  'koguni': 459,
#  'seni': 460,
#  'võim': 461,
#  'unustama': 462,
#  'ligi': 463,
#  'tütar': 464,
#  'kirjanik': 465,
#  'võitlus': 466,
#  'rahu': 467,
#  'i': 468,
#  'müüma': 469,
#  'seletama': 470,
#  'hoone': 471,
#  'kaua': 472,
#  'protsent': 473,
#  'materjal': 474,
#  'külg': 475,
#  'punkt': 476,
#  'üksnes': 477,
#  'ülikool': 478,
#  'taha': 479,
#  'soov': 480,
#  'kunstnik': 481,
#  'kostma': 482,
#  'kohal': 483,
#  'sügis': 484,
#  'alt': 485,
#  'rida': 486,
#  'siit': 487,
#  'kunst': 488,
#  'ainus': 489,
#  'koer': 490,
#  'september': 491,
#  'sees': 492,
#  'juhtima': 493,
#  'jaan': 494,
#  'juhataja': 495,
#  'noormees': 496,
#  'ajalugu': 497,
#  'laev': 498,
#  'jooma': 499,
#  'suruma': 500,
#  'varsti': 501,
#  'kirjandus': 502,
#  'vorm': 503,
#  'mil': 504,
#  'huvitav': 505,
#  'mai': 506,
#  'õpilane': 507,
#  'palk': 508,
#  'minut': 509,
#  'pank': 510,
#  'muusika': 511,
#  'kerge': 512,
#  'selguma': 513,
#  'korraga': 514,
#  'armastama': 515,
#  'veelgi': 516,
#  'üksik': 517,
#  'nimelt': 518,
#  'tuli': 519,
#  'halb': 520,
#  'paik': 521,
#  'viskama': 522,
#  'saksamaa': 523,
#  'teadmine': 524,
#  'tarvis': 525,
#  'asemel': 526,
#  'kujutama': 527,
#  'võrdlema': 528,
#  'pealegi': 529,
#  'ettepanek': 530,
#  'voodi': 531,
#  'mure': 532,
#  'paber': 533,
#  'määrama': 534,
#  'hirm': 535,
#  'peremees': 536,
#  'saar': 537,
#  'hall': 538,
#  'tuntud': 539,
#  'ühine': 540,
#  'õnn': 541,
#  'toetama': 542,
#  'igaüks': 543,
#  'lausuma': 544,
#  'valgus': 545,
#  'hindama': 546,
#  'amet': 547,
#  'm.': 548,
#  'kõrgem': 549,
#  'kõrv': 550,
#  'tööline': 551,
#  'jõgi': 552,
#  'viga': 553,
#  'lai': 554,
#  'sõrm': 555,
#  'sündmus': 556,
#  'joon': 557,
#  'armastus': 558,
#  'noh': 559,
#  'perekond': 560,
#  'seesama': 561,
#  'korter': 562,
#  'laul': 563,
#  'tükk': 564,
#  'lõppema': 565,
#  'liikumine': 566,
#  'ilm': 567,
#  'kuju': 568,
#  'politsei': 569,
#  'pere': 570,
#  'lihtne': 571,
#  'valmistama': 572,
#  'balti': 573,
#  'täitmine': 574,
#  'talv': 575,
#  'kuus': 576,
#  'kukkuma': 577,
#  'küllalt': 578,
#  'muld': 579,
#  'vend': 580,
#  'mõju': 581,
#  'juus': 582,
#  'üksi': 583,
#  'sekretär': 584,
#  'hobune': 585,
#  'vedama': 586,
#  'tulevik': 587,
#  'komme': 588,
#  'toime': 589,
#  'talu': 590,
#  'valimine': 591,
#  'omanik': 592,
#  'leiduma': 593,
#  'jüri': 594,
#  'loodus': 595,
#  'lühike': 596,
#  'puutuma': 597,
#  'sada': 598,
#  'haige': 599,
#  'tõsi': 600,
#  'vajuma': 601,
#  'keerama': 602,
#  'rõõm': 603,
#  'põhi': 604,
#  'mõnikord': 605,
#  'jagama': 606,
#  'vaikima': 607,
#  'ots': 608,
#  'ääres': 609,
#  'segama': 610,
#  'külaline': 611,
#  'veri': 612,
#  'lükkama': 613,
#  'üksteise': 614,
#  'lendama': 615,
#  'kirik': 616,
#  'vari': 617,
#  'paremini': 618,
#  'klass': 619,
#  'peeter': 620,
#  'kaitsma': 621,
#  'elanik': 622,
#  'kaitse': 623,
#  'kongress': 624,
#  'põld': 625,
#  'teadus': 626,
#  'ammu': 627,
#  'tõsine': 628,
#  'õu': 629,
#  'lugeja': 630,
#  'märk': 631,
#  'mõjuma': 632,
#  'lootus': 633,
#  'minister': 634,
#  'tabama': 635,
#  'tagant': 636,
#  'kiire': 637,
#  'vara': 638,
#  'n': 639,
#  'pärnu': 640,
#  'nurk': 641,
#  'asutus': 642,
#  'pealt': 643,
#  'lind': 644,
#  'rind': 645,
#  'püsti': 646,
#  'niisama': 647,
#  'saal': 648,
#  'e.': 649,
#  'vaim': 650,
#  'läti': 651,
#  'kallas': 652,
#  'kodanik': 653,
#  'kahju': 654,
#  'kõne': 655,
#  'naeratama': 656,
#  'põrand': 657,
#  'kasu': 658,
#  'riie': 659,
#  'tähtsus': 660,
#  'lõikama': 661,
#  'tänu': 662,
#  'kasvatama': 663,
#  'arst': 664,
#  'saatus': 665,
#  'abil': 666,
#  'mägi': 667,
#  'aed': 668,
#  'teade': 669,
#  'piim': 670,
#  'masin': 671,
#  'õpetama': 672,
#  'madal': 673,
#  'lumi': 674,
#  'hüüdma': 675,
#  'teineteise': 676,
#  'komisjon': 677,
#  'viibima': 678,
#  'p': 679,
#  'vabadus': 680,
#  'teenima': 681,
#  'nina': 682,
#  'ah': 683,
#  'surema': 684,
#  'elav': 685,
#  'vaevalt': 686,
#  'kael': 687,
#  'millal': 688,
#  'turg': 689,
#  'hulka': 690,
#  'tänavu': 691,
#  'laulma': 692,
#  'number': 693,
#  'käik': 694,
#  'käesolev': 695,
#  'koosolek': 696,
#  'näitus': 697,
#  'h.': 698,
#  'teatud': 699,
#  'vahtima': 700,
#  'suurus': 701,
#  'vili': 702,
#  'soovitama': 703,
#  'mitmesugune': 704,
#  'vahe': 705,
#  'väärtus': 706,
#  'õieti': 707,
#  'tagajärg': 708,
#  'pikem': 709,
#  'julgema': 710,
#  'poolest': 711,
#  'kallis': 712,
#  'vaikne': 713,
#  'köök': 714,
#  'pime': 715,
#  'klaas': 716,
#  'vahetama': 717,
#  'mälestus': 718,
#  'juuli': 719,
#  'roheline': 720,
#  'tihti': 721,
#  'õde': 722,
#  'osakond': 723,
#  'värv': 724,
#  'värav': 725,
#  'tõde': 726,
#  'e': 727,
#  'kuulutama': 728,
#  'tervis': 729,
#  'hool': 730,
#  'pind': 731,
#  'lehm': 732,
#  'saadud': 733,
#  'imelik': 734,
#  'missugune': 735,
#  'raskus': 736,
#  'kõndima': 737,
#  'koguma': 738,
#  'avalik': 739,
#  'sisu': 740,
#  'mari': 741,
#  'kordama': 742,
#  'seitse': 743,
#  'järv': 744,
#  'vähene': 745,
#  'senine': 746,
#  'nutma': 747,
#  'tasku': 748,
#  'kõlama': 749,
#  'üliõpilane': 750,
#  'tähtsam': 751,
#  'kaup': 752,
#  'nõu': 753,
#  'kurat': 754,
#  'surnud': 755,
#  'protsess': 756,
#  'kiskuma': 757,
#  'nimetatud': 758,
#  'ronima': 759,
#  't': 760,
#  'keelama': 761,
#  'trepp': 762,
#  'kippuma': 763,
#  'tume': 764,
#  'seekord': 765,
#  'tasuma': 766,
#  'ehitus': 767,
#  'teisiti': 768,
#  'homme': 769,
#  'meister': 770,
#  'i.': 771,
#  'detsember': 772,
#  'nahk': 773,
#  'parandama': 774,
#  'valitsema': 775,
#  'põhjal': 776,
#  'juhan': 777,
#  'rong': 778,
#  'väljas': 779,
#  'lill': 780,
#  'seas': 781,
#  'sugugi': 782,
#  'sõit': 783,
#  'pistma': 784,
#  'saamine': 785,
#  'tõsiselt': 786,
#  'summa': 787,
#  'harjuma': 788,
#  'r.': 789,
#  'hiina': 790,
#  'noorem': 791,
#  'võitlema': 792,
#  'suurendama': 793,
#  'kestma': 794,
#  'kannatama': 795,
#  'pärima': 796,
#  'k.': 797,
#  'katus': 798,
#  'poola': 799,
#  'l': 800,
#  'v': 801,
#  'kätte': 802,
#  'katma': 803,
#  'murdma': 804,
#  'ühtlasi': 805,
#  'õnnelik': 806,
#  'häda': 807,
#  'narva': 808,
#  'külge': 809,
#  'sügav': 810,
#  'ärkama': 811,
#  'kaheksa': 812,
#  'tänane': 813,
#  'imestama': 814,
#  'ajakirjandus': 815,
#  'täielik': 816,
#  'raamatukogu': 817,
#  'aprill': 818,
#  'lähedal': 819,
#  'katsuma': 820,
#  'vaikus': 821,
#  'kahjuks': 822,
#  'pudel': 823,
#  'ükskõik': 824,
#  'korralik': 825,
#  'varjama': 826,
#  'läbirääkimine': 827,
#  'viin': 828,
#  'vastane': 829,
#  'hoolimata': 830,
#  'kaunis': 831,
#  'haigus': 832,
#  'kahtlus': 833,
#  'sakslane': 834,
#  'toon': 835,
#  'lõuna': 836,
#  'vägi': 837,
#  'selts': 838,
#  'juhatus': 839,
#  'nr': 840,
#  'kitsas': 841,
#  'käest': 842,
#  'leppima': 843,
#  'katse': 844,
#  'ümbrus': 845,
#  'iseloom': 846,
#  'sinine': 847,
#  'kaarel': 848,
#  'hüppama': 849,
#  'kauge': 850,
#  'kuluma': 851,
#  'hammas': 852,
#  'öösel': 853,
#  'vahest': 854,
#  'korraks': 855,
#  'rikkuma': 856,
#  'karjuma': 857,
#  'ehitamine': 858,
#  'värske': 859,
#  'eemale': 860,
#  'vahelt': 861,
#  'laiali': 862,
#  'seltsimees': 863,
#  'saadik': 864,
#  'põlema': 865,
#  'r': 866,
#  'pealinn': 867,
#  'liha': 868,
#  'leib': 869,
#  'ilmunud': 870,
#  'vald': 871,
#  'lause': 872,
#  'l.': 873,
#  'eestimaa': 874,
#  'nimel': 875,
#  'kakskümmend': 876,
#  'kodumaa': 877,
#  'tapma': 878,
#  'keskel': 879,
#  'aimama': 880,
#  'pehme': 881,
#  'täht': 882,
#  'nähtus': 883,
#  'kõrgus': 884,
#  'järsku': 885,
#  'harva': 886,
#  'hirmus': 887,
#  'kauplus': 888,
#  'kaugel': 889,
#  'terav': 890,
#  'ohvitser': 891,
#  'maantee': 892,
#  'sadam': 893,
#  'teatav': 894,
#  'kiitma': 895,
#  'huul': 896,
#  'puudus': 897,
#  'püha': 898,
#  'jutustama': 899,
#  'võimalikult': 900,
#  'hiljuti': 901,
#  'jaak': 902,
#  'mujal': 903,
#  'professor': 904,
#  'kuningas': 905,
#  'saak': 906,
#  'lähenema': 907,
#  'silmitsema': 908,
#  'koor': 909,
#  'k': 910,
#  'tool': 911,
#  'prantsuse': 912,
#  'kuum': 913,
#  'kiirus': 914,
#  'rada': 915,
#  'käsk': 916,
#  'siduma': 917,
#  'kõva': 918,
#  'laine': 919,
#  'paul': 920,
#  'n.': 921,
#  'teel': 922,
#  'pisike': 923,
#  'ametlik': 924,
#  'vihm': 925,
#  'jälg': 926,
#  'vaev': 927,
#  'määratud': 928,
#  'kaugele': 929,
#  'kontsert': 930,
#  'loodud': 931,
#  'inglise': 932,
#  'äratama': 933,
#  'rahulikult': 934,
#  'paljas': 935,
#  'kuri': 936,
#  'karl': 937,
#  'juurest': 938,
#  'põgenema': 939,
#  'päästma': 940,
#  'neljas': 941,
#  'sirutama': 942,
#  'omadus': 943,
#  'tegelane': 944,
#  'rakvere': 945,
#  'tulevane': 946,
#  'pühapäev': 947,
#  'lähem': 948,
#  'mõistus': 949,
#  'tuletama': 950,
#  'peetud': 951,
#  'toimetus': 952,
#  'loomulik': 953,
#  'puhkama': 954,
#  'siinne': 955,
#  'süüdi': 956,
#  'omandama': 957,
#  'liiv': 958,
#  'tähele': 959,
#  'uhke': 960,
#  'tõstmine': 961,
#  'põlv': 962,
#  'raud': 963,
#  'suits': 964,
#  'haridus': 965,
#  'käes': 966,
#  'kuiv': 967,
#  'igapäevane': 968,
#  'rahul': 969,
#  'märts': 970,
#  'komitee': 971,
#  'abinõu': 972,
#  'hoog': 973,
#  'viimaks': 974,
#  'vaenlane': 975,
#  'väsinud': 976,
#  'peagi': 977,
#  'pihk': 978,
#  'vang': 979,
#  'tungima': 980,
#  'riia': 981,
#  'nimekiri': 982,
#  'ühendus': 983,
#  'helsingi': 984,
#  'tutvustama': 985,
#  'kurb': 986,
#  'kuulus': 987,
#  'jaapan': 988,
#  'laupäev': 989,
#  'ähvardama': 990,
#  'avatud': 991,
#  'tänama': 992,
#  'muretsema': 993,
#  's.': 994,
#  'sõnama': 995,
#  'vaidlema': 996,
#  'inglismaa': 997,
#  'ulatama': 998,
#  'tulev': 999,
#  ...}

# %%
idxs
# Out:
# ['olema',
#  'ja',
#  'tema',
#  'see',
#  'mina',
#  'ei',
#  'et',
#  'mis',
#  'kui',
#  'ka',
#  'oma',
#  'aga',
#  'saama',
#  'sina',
#  'ning',
#  'siis',
#  'kes',
#  'või',
#  'tulema',
#  'ise',
#  'pidama',
#  'aasta',
#  'üks',
#  'nii',
#  'kõik',
#  'võima',
#  'tegema',
#  'teine',
#  'nagu',
#  'minema',
#  'ütlema',
#  'eesti',
#  'veel',
#  'aeg',
#  'jääma',
#  'võtma',
#  'juba',
#  'mees',
#  'inimene',
#  'kuid',
#  'hakkama',
#  'teadma',
#  'kas',
#  'suur',
#  'miski',
#  'välja',
#  'ära',
#  'nägema',
#  'nüüd',
#  'andma',
#  'üle',
#  'tahtma',
#  'mitte',
#  'palju',
#  'mõni',
#  'töö',
#  'vaid',
#  'ainult',
#  'kord',
#  'uus',
#  'küll',
#  'vastu',
#  'kus',
#  'pärast',
#  'kaks',
#  'sest',
#  'naine',
#  'vaatama',
#  'käsi',
#  'enam',
#  'esimene',
#  'iga',
#  'panema',
#  'päev',
#  'eest',
#  'ju',
#  'siin',
#  'peale',
#  'ega',
#  'rääkima',
#  'asi',
#  'keegi',
#  'mõtlema',
#  'tundma',
#  'käima',
#  'kuidas',
#  'väga',
#  'silm',
#  'jõudma',
#  'elu',
#  'tagasi',
#  'hea',
#  'sõna',
#  'seal',
#  'kõige',
#  'läbi',
#  'laps',
#  'ikka',
#  'kogu',
#  'viimane',
#  'mingi',
#  'leidma',
#  'maa',
#  'arvama',
#  'tallinn',
#  'ette',
#  'osa',
#  'rohkem',
#  'pea',
#  'seisma',
#  'isegi',
#  'praegu',
#  'riik',
#  'linn',
#  'alla',
#  'sama',
#  'küsima',
#  'tooma',
#  'just',
#  'mitu',
#  'elama',
#  'enne',
#  'mõte',
#  'pool',
#  'vahel',
#  'ema',
#  'muu',
#  'poole',
#  'vana',
#  'väike',
#  'kolm',
#  'noor',
#  'kohta',
#  'tee',
#  'all',
#  'ees',
#  'kodu',
#  'rahvas',
#  'istuma',
#  'juurde',
#  'jätma',
#  'koht',
#  'ootama',
#  'maja',
#  'juht',
#  'viima',
#  'koos',
#  'kirjutama',
#  'a',
#  'siiski',
#  'edasi',
#  'maailm',
#  'kokku',
#  'poolt',
#  'püüdma',
#  'laskma',
#  'miks',
#  'kuni',
#  'isa',
#  'kuulma',
#  'jälle',
#  'alles',
#  'poiss',
#  'muutuma',
#  'suutma',
#  'astuma',
#  'sõitma',
#  'nägu',
#  'tartu',
#  'kohe',
#  'küsimus',
#  'muidugi',
#  'lugema',
#  'keel',
#  'uks',
#  'suurem',
#  'pikk',
#  'üles',
#  'sisse',
#  'ehk',
#  'maha',
#  'vastama',
#  'lõpp',
#  'niisugune',
#  'kuigi',
#  'alati',
#  'näitama',
#  'hoidma',
#  'jalg',
#  'vesi',
#  'juures',
#  'raha',
#  'tüdruk',
#  'oskama',
#  'jutt',
#  'nimi',
#  'ümber',
#  'parem',
#  'valge',
#  'vaja',
#  'valitsus',
#  'tõusma',
#  'kunagi',
#  'võimalik',
#  'hästi',
#  'raamat',
#  'ometi',
#  'kinni',
#  'hiljem',
#  'õige',
#  'hääl',
#  'lahti',
#  'tekkima',
#  'laud',
#  'järgmine',
#  'kaasa',
#  'täis',
#  'ajama',
#  'meel',
#  'raske',
#  'mööda',
#  'paar',
#  'töötama',
#  'pilk',
#  'viis',
#  'taga',
#  'lööma',
#  'mõistma',
#  'tuba',
#  'kuu',
#  'aru',
#  'jah',
#  'saatma',
#  'asuma',
#  'järele',
#  'aitama',
#  'kutsuma',
#  'kandma',
#  'otsima',
#  'mängima',
#  'kool',
#  'miljon',
#  'tähendama',
#  '',
#  'õhtu',
#  'kindel',
#  'kasvama',
#  'peaaegu',
#  'kaduma',
#  'tegevus',
#  'õigus',
#  'ilma',
#  'nõudma',
#  'lihtsalt',
#  'maksma',
#  'jaoks',
#  'kell',
#  'a.',
#  'liiga',
#  'juhtuma',
#  'kiri',
#  'sinna',
#  'uskuma',
#  'ülesanne',
#  'paistma',
#  'jõud',
#  'hoopis',
#  'selg',
#  'jooksul',
#  'tund',
#  'kuuluma',
#  'moskva',
#  'lubama',
#  'tõstma',
#  'soome',
#  'must',
#  'vist',
#  'nädal',
#  'lugu',
#  'terve',
#  'täna',
#  'varem',
#  'ettevõte',
#  'vabariik',
#  'algus',
#  'põhjus',
#  'kinnitama',
#  'päris',
#  'kuhu',
#  'mõlema',
#  'otsus',
#  'aken',
#  'otsustama',
#  'alus',
#  'algama',
#  'neli',
#  'liige',
#  'üsna',
#  'endine',
#  'tegemine',
#  'tõmbama',
#  'täitma',
#  'vanem',
#  'tohtima',
#  'pakkuma',
#  'meri',
#  'märkama',
#  'süda',
#  'mets',
#  'hommik',
#  'selge',
#  'võõras',
#  'kuna',
#  'täiesti',
#  'õppima',
#  'tõesti',
#  'kõrval',
#  'lõpetama',
#  'vähemalt',
#  'suu',
#  'umbes',
#  'looma',
#  'tehtud',
#  'nimetama',
#  'seadus',
#  'alustama',
#  'lisama',
#  'esimees',
#  'puu',
#  'mäng',
#  'valima',
#  'kartma',
#  'teatama',
#  'ilus',
#  'liikuma',
#  'samm',
#  'tühi',
#  'eks',
#  'ajal',
#  'kuulama',
#  'kolmas',
#  'paluma',
#  'siia',
#  'uuesti',
#  'näima',
#  'president',
#  'nõnda',
#  'lootma',
#  'punane',
#  'abi',
#  'hing',
#  'poeg',
#  'veidi',
#  'sõda',
#  'pilt',
#  'arv',
#  'ilmuma',
#  'langema',
#  'valmis',
#  'mäletama',
#  'avama',
#  'sõber',
#  'kust',
#  'kohalik',
#  'vähem',
#  'ostma',
#  'sööma',
#  'eesmärk',
#  'leht',
#  'tõttu',
#  'kindlasti',
#  'vähe',
#  'sattuma',
#  'ruum',
#  'suvi',
#  'kümme',
#  'plaan',
#  'kõrge',
#  'sealt',
#  'loom',
#  'meeldima',
#  'tähtis',
#  'küla',
#  'tunnistama',
#  'kuidagi',
#  'praegune',
#  'sein',
#  'jooksma',
#  'avaldama',
#  'peal',
#  'tuhat',
#  'võitma',
#  'saksa',
#  'soovima',
#  'pöörama',
#  'keskmine',
#  'külm',
#  'otsa',
#  'öö',
#  'vaba',
#  'magama',
#  'muutma',
#  'sündima',
#  'antud',
#  'ajaleht',
#  'olev',
#  'ringi',
#  'hulgas',
#  'kohus',
#  'surm',
#  'naerma',
#  'õpetaja',
#  'kõrvale',
#  'sellepärast',
#  'uurima',
#  'leping',
#  'õhk',
#  'vahele',
#  'pisut',
#  'kõnelema',
#  'ehitama',
#  'korral',
#  'tegu',
#  'tuttav',
#  'hulk',
#  'tugev',
#  'piir',
#  'kaotama',
#  'seadma',
#  'heitma',
#  'tuul',
#  'hind',
#  'kaudu',
#  'puuduma',
#  'kevad',
#  'seisukoht',
#  'august',
#  'keha',
#  'otse',
#  'seega',
#  'vastus',
#  'pääsema',
#  'soe',
#  'muidu',
#  'm',
#  'päike',
#  'jne',
#  'ala',
#  'võit',
#  'õlg',
#  'puhas',
#  'järel',
#  'kivi',
#  'rootsi',
#  'direktor',
#  'j.',
#  'taevas',
#  'lahkuma',
#  'sundima',
#  'koguni',
#  'seni',
#  'võim',
#  'unustama',
#  'ligi',
#  'tütar',
#  'kirjanik',
#  'võitlus',
#  'rahu',
#  'i',
#  'müüma',
#  'seletama',
#  'hoone',
#  'kaua',
#  'protsent',
#  'materjal',
#  'külg',
#  'punkt',
#  'üksnes',
#  'ülikool',
#  'taha',
#  'soov',
#  'kunstnik',
#  'kostma',
#  'kohal',
#  'sügis',
#  'alt',
#  'rida',
#  'siit',
#  'kunst',
#  'ainus',
#  'koer',
#  'september',
#  'sees',
#  'juhtima',
#  'jaan',
#  'juhataja',
#  'noormees',
#  'ajalugu',
#  'laev',
#  'jooma',
#  'suruma',
#  'varsti',
#  'kirjandus',
#  'vorm',
#  'mil',
#  'huvitav',
#  'mai',
#  'õpilane',
#  'palk',
#  'minut',
#  'pank',
#  'muusika',
#  'kerge',
#  'selguma',
#  'korraga',
#  'armastama',
#  'veelgi',
#  'üksik',
#  'nimelt',
#  'tuli',
#  'halb',
#  'paik',
#  'viskama',
#  'saksamaa',
#  'teadmine',
#  'tarvis',
#  'asemel',
#  'kujutama',
#  'võrdlema',
#  'pealegi',
#  'ettepanek',
#  'voodi',
#  'mure',
#  'paber',
#  'määrama',
#  'hirm',
#  'peremees',
#  'saar',
#  'hall',
#  'tuntud',
#  'ühine',
#  'õnn',
#  'toetama',
#  'igaüks',
#  'lausuma',
#  'valgus',
#  'hindama',
#  'amet',
#  'm.',
#  'kõrgem',
#  'kõrv',
#  'tööline',
#  'jõgi',
#  'viga',
#  'lai',
#  'sõrm',
#  'sündmus',
#  'joon',
#  'armastus',
#  'noh',
#  'perekond',
#  'seesama',
#  'korter',
#  'laul',
#  'tükk',
#  'lõppema',
#  'liikumine',
#  'ilm',
#  'kuju',
#  'politsei',
#  'pere',
#  'lihtne',
#  'valmistama',
#  'balti',
#  'täitmine',
#  'talv',
#  'kuus',
#  'kukkuma',
#  'küllalt',
#  'muld',
#  'vend',
#  'mõju',
#  'juus',
#  'üksi',
#  'sekretär',
#  'hobune',
#  'vedama',
#  'tulevik',
#  'komme',
#  'toime',
#  'talu',
#  'valimine',
#  'omanik',
#  'leiduma',
#  'jüri',
#  'loodus',
#  'lühike',
#  'puutuma',
#  'sada',
#  'haige',
#  'tõsi',
#  'vajuma',
#  'keerama',
#  'rõõm',
#  'põhi',
#  'mõnikord',
#  'jagama',
#  'vaikima',
#  'ots',
#  'ääres',
#  'segama',
#  'külaline',
#  'veri',
#  'lükkama',
#  'üksteise',
#  'lendama',
#  'kirik',
#  'vari',
#  'paremini',
#  'klass',
#  'peeter',
#  'kaitsma',
#  'elanik',
#  'kaitse',
#  'kongress',
#  'põld',
#  'teadus',
#  'ammu',
#  'tõsine',
#  'õu',
#  'lugeja',
#  'märk',
#  'mõjuma',
#  'lootus',
#  'minister',
#  'tabama',
#  'tagant',
#  'kiire',
#  'vara',
#  'n',
#  'pärnu',
#  'nurk',
#  'asutus',
#  'pealt',
#  'lind',
#  'rind',
#  'püsti',
#  'niisama',
#  'saal',
#  'e.',
#  'vaim',
#  'läti',
#  'kallas',
#  'kodanik',
#  'kahju',
#  'kõne',
#  'naeratama',
#  'põrand',
#  'kasu',
#  'riie',
#  'tähtsus',
#  'lõikama',
#  'tänu',
#  'kasvatama',
#  'arst',
#  'saatus',
#  'abil',
#  'mägi',
#  'aed',
#  'teade',
#  'piim',
#  'masin',
#  'õpetama',
#  'madal',
#  'lumi',
#  'hüüdma',
#  'teineteise',
#  'komisjon',
#  'viibima',
#  'p',
#  'vabadus',
#  'teenima',
#  'nina',
#  'ah',
#  'surema',
#  'elav',
#  'vaevalt',
#  'kael',
#  'millal',
#  'turg',
#  'hulka',
#  'tänavu',
#  'laulma',
#  'number',
#  'käik',
#  'käesolev',
#  'koosolek',
#  'näitus',
#  'h.',
#  'teatud',
#  'vahtima',
#  'suurus',
#  'vili',
#  'soovitama',
#  'mitmesugune',
#  'vahe',
#  'väärtus',
#  'õieti',
#  'tagajärg',
#  'pikem',
#  'julgema',
#  'poolest',
#  'kallis',
#  'vaikne',
#  'köök',
#  'pime',
#  'klaas',
#  'vahetama',
#  'mälestus',
#  'juuli',
#  'roheline',
#  'tihti',
#  'õde',
#  'osakond',
#  'värv',
#  'värav',
#  'tõde',
#  'e',
#  'kuulutama',
#  'tervis',
#  'hool',
#  'pind',
#  'lehm',
#  'saadud',
#  'imelik',
#  'missugune',
#  'raskus',
#  'kõndima',
#  'koguma',
#  'avalik',
#  'sisu',
#  'mari',
#  'kordama',
#  'seitse',
#  'järv',
#  'vähene',
#  'senine',
#  'nutma',
#  'tasku',
#  'kõlama',
#  'üliõpilane',
#  'tähtsam',
#  'kaup',
#  'nõu',
#  'kurat',
#  'surnud',
#  'protsess',
#  'kiskuma',
#  'nimetatud',
#  'ronima',
#  't',
#  'keelama',
#  'trepp',
#  'kippuma',
#  'tume',
#  'seekord',
#  'tasuma',
#  'ehitus',
#  'teisiti',
#  'homme',
#  'meister',
#  'i.',
#  'detsember',
#  'nahk',
#  'parandama',
#  'valitsema',
#  'põhjal',
#  'juhan',
#  'rong',
#  'väljas',
#  'lill',
#  'seas',
#  'sugugi',
#  'sõit',
#  'pistma',
#  'saamine',
#  'tõsiselt',
#  'summa',
#  'harjuma',
#  'r.',
#  'hiina',
#  'noorem',
#  'võitlema',
#  'suurendama',
#  'kestma',
#  'kannatama',
#  'pärima',
#  'k.',
#  'katus',
#  'poola',
#  'l',
#  'v',
#  'kätte',
#  'katma',
#  'murdma',
#  'ühtlasi',
#  'õnnelik',
#  'häda',
#  'narva',
#  'külge',
#  'sügav',
#  'ärkama',
#  'kaheksa',
#  'tänane',
#  'imestama',
#  'ajakirjandus',
#  'täielik',
#  'raamatukogu',
#  'aprill',
#  'lähedal',
#  'katsuma',
#  'vaikus',
#  'kahjuks',
#  'pudel',
#  'ükskõik',
#  'korralik',
#  'varjama',
#  'läbirääkimine',
#  'viin',
#  'vastane',
#  'hoolimata',
#  'kaunis',
#  'haigus',
#  'kahtlus',
#  'sakslane',
#  'toon',
#  'lõuna',
#  'vägi',
#  'selts',
#  'juhatus',
#  'nr',
#  'kitsas',
#  'käest',
#  'leppima',
#  'katse',
#  'ümbrus',
#  'iseloom',
#  'sinine',
#  'kaarel',
#  'hüppama',
#  'kauge',
#  'kuluma',
#  'hammas',
#  'öösel',
#  'vahest',
#  'korraks',
#  'rikkuma',
#  'karjuma',
#  'ehitamine',
#  'värske',
#  'eemale',
#  'vahelt',
#  'laiali',
#  'seltsimees',
#  'saadik',
#  'põlema',
#  'r',
#  'pealinn',
#  'liha',
#  'leib',
#  'ilmunud',
#  'vald',
#  'lause',
#  'l.',
#  'eestimaa',
#  'nimel',
#  'kakskümmend',
#  'kodumaa',
#  'tapma',
#  'keskel',
#  'aimama',
#  'pehme',
#  'täht',
#  'nähtus',
#  'kõrgus',
#  'järsku',
#  'harva',
#  'hirmus',
#  'kauplus',
#  'kaugel',
#  'terav',
#  'ohvitser',
#  'maantee',
#  'sadam',
#  'teatav',
#  'kiitma',
#  'huul',
#  'puudus',
#  'püha',
#  'jutustama',
#  'võimalikult',
#  'hiljuti',
#  'jaak',
#  'mujal',
#  'professor',
#  'kuningas',
#  'saak',
#  'lähenema',
#  'silmitsema',
#  'koor',
#  'k',
#  'tool',
#  'prantsuse',
#  'kuum',
#  'kiirus',
#  'rada',
#  'käsk',
#  'siduma',
#  'kõva',
#  'laine',
#  'paul',
#  'n.',
#  'teel',
#  'pisike',
#  'ametlik',
#  'vihm',
#  'jälg',
#  'vaev',
#  'määratud',
#  'kaugele',
#  'kontsert',
#  'loodud',
#  'inglise',
#  'äratama',
#  'rahulikult',
#  'paljas',
#  'kuri',
#  'karl',
#  'juurest',
#  'põgenema',
#  'päästma',
#  'neljas',
#  'sirutama',
#  'omadus',
#  'tegelane',
#  'rakvere',
#  'tulevane',
#  'pühapäev',
#  'lähem',
#  'mõistus',
#  'tuletama',
#  'peetud',
#  'toimetus',
#  'loomulik',
#  'puhkama',
#  'siinne',
#  'süüdi',
#  'omandama',
#  'liiv',
#  'tähele',
#  'uhke',
#  'tõstmine',
#  'põlv',
#  'raud',
#  'suits',
#  'haridus',
#  'käes',
#  'kuiv',
#  'igapäevane',
#  'rahul',
#  'märts',
#  'komitee',
#  'abinõu',
#  'hoog',
#  'viimaks',
#  'vaenlane',
#  'väsinud',
#  'peagi',
#  'pihk',
#  'vang',
#  'tungima',
#  'riia',
#  'nimekiri',
#  'ühendus',
#  'helsingi',
#  'tutvustama',
#  'kurb',
#  'kuulus',
#  'jaapan',
#  'laupäev',
#  'ähvardama',
#  'avatud',
#  'tänama',
#  'muretsema',
#  's.',
#  'sõnama',
#  'vaidlema',
#  'inglismaa',
#  'ulatama',
#  'tulev',
#  ...]

# %%
all_words
# Out:
# ['olema',
#  'ja',
#  'tema',
#  'see',
#  'mina',
#  'ei',
#  'et',
#  'mis',
#  'kui',
#  'ka',
#  'oma',
#  'aga',
#  'saama',
#  'sina',
#  'ning',
#  'siis',
#  'kes',
#  'või',
#  'tulema',
#  'ise',
#  'pidama',
#  'aasta',
#  'üks',
#  'nii',
#  'kõik',
#  'võima',
#  'tegema',
#  'teine',
#  'nagu',
#  'minema',
#  'ütlema',
#  'eesti',
#  'veel',
#  'aeg',
#  'jääma',
#  'võtma',
#  'juba',
#  'mees',
#  'inimene',
#  'kuid',
#  'hakkama',
#  'teadma',
#  'kas',
#  'suur',
#  'miski',
#  'välja',
#  'ära',
#  'nägema',
#  'nüüd',
#  'andma',
#  'üle',
#  'tahtma',
#  'mitte',
#  'palju',
#  'mõni',
#  'töö',
#  'vaid',
#  'ainult',
#  'kord',
#  'uus',
#  'küll',
#  'vastu',
#  'kus',
#  'pärast',
#  'kaks',
#  'sest',
#  'naine',
#  'vaatama',
#  'käsi',
#  'enam',
#  'esimene',
#  'iga',
#  'panema',
#  'päev',
#  'eest',
#  'ju',
#  'siin',
#  'peale',
#  'ega',
#  'rääkima',
#  'asi',
#  'keegi',
#  'mõtlema',
#  'tundma',
#  'käima',
#  'kuidas',
#  'väga',
#  'silm',
#  'jõudma',
#  'elu',
#  'tagasi',
#  'hea',
#  'sõna',
#  'seal',
#  'kõige',
#  'läbi',
#  'laps',
#  'ikka',
#  'kogu',
#  'viimane',
#  'mingi',
#  'leidma',
#  'maa',
#  'arvama',
#  'tallinn',
#  'ette',
#  'osa',
#  'rohkem',
#  'pea',
#  'seisma',
#  'isegi',
#  'praegu',
#  'riik',
#  'linn',
#  'alla',
#  'sama',
#  'küsima',
#  'tooma',
#  'just',
#  'mitu',
#  'elama',
#  'enne',
#  'mõte',
#  'pool',
#  'vahel',
#  'ema',
#  'muu',
#  'poole',
#  'vana',
#  'väike',
#  'kolm',
#  'noor',
#  'kohta',
#  'tee',
#  'all',
#  'ees',
#  'kodu',
#  'rahvas',
#  'istuma',
#  'juurde',
#  'jätma',
#  'koht',
#  'ootama',
#  'maja',
#  'juht',
#  'viima',
#  'koos',
#  'kirjutama',
#  'a',
#  'siiski',
#  'edasi',
#  'maailm',
#  'kokku',
#  'poolt',
#  'püüdma',
#  'laskma',
#  'miks',
#  'kuni',
#  'isa',
#  'kuulma',
#  'jälle',
#  'alles',
#  'poiss',
#  'muutuma',
#  'suutma',
#  'astuma',
#  'sõitma',
#  'nägu',
#  'tartu',
#  'kohe',
#  'küsimus',
#  'muidugi',
#  'lugema',
#  'keel',
#  'uks',
#  'suurem',
#  'pikk',
#  'üles',
#  'sisse',
#  'ehk',
#  'maha',
#  'vastama',
#  'lõpp',
#  'niisugune',
#  'kuigi',
#  'alati',
#  'näitama',
#  'hoidma',
#  'jalg',
#  'vesi',
#  'juures',
#  'raha',
#  'tüdruk',
#  'oskama',
#  'jutt',
#  'nimi',
#  'ümber',
#  'parem',
#  'valge',
#  'vaja',
#  'valitsus',
#  'tõusma',
#  'kunagi',
#  'võimalik',
#  'hästi',
#  'raamat',
#  'ometi',
#  'kinni',
#  'hiljem',
#  'õige',
#  'hääl',
#  'lahti',
#  'tekkima',
#  'laud',
#  'järgmine',
#  'kaasa',
#  'täis',
#  'ajama',
#  'meel',
#  'raske',
#  'mööda',
#  'paar',
#  'töötama',
#  'pilk',
#  'viis',
#  'taga',
#  'lööma',
#  'mõistma',
#  'tuba',
#  'kuu',
#  'aru',
#  'jah',
#  'saatma',
#  'asuma',
#  'järele',
#  'aitama',
#  'kutsuma',
#  'kandma',
#  'otsima',
#  'mängima',
#  'kool',
#  'miljon',
#  'tähendama',
#  '',
#  'õhtu',
#  'kindel',
#  'kasvama',
#  'peaaegu',
#  'kaduma',
#  'tegevus',
#  'õigus',
#  'ilma',
#  'nõudma',
#  'lihtsalt',
#  'maksma',
#  'jaoks',
#  'kell',
#  'a.',
#  'liiga',
#  'juhtuma',
#  'kiri',
#  'sinna',
#  'uskuma',
#  'ülesanne',
#  'paistma',
#  'jõud',
#  'hoopis',
#  'selg',
#  'jooksul',
#  'tund',
#  'kuuluma',
#  'moskva',
#  'lubama',
#  'tõstma',
#  'soome',
#  'must',
#  'vist',
#  'nädal',
#  'lugu',
#  'terve',
#  'täna',
#  'varem',
#  'ettevõte',
#  'vabariik',
#  'algus',
#  'põhjus',
#  'kinnitama',
#  'päris',
#  'kuhu',
#  'mõlema',
#  'otsus',
#  'aken',
#  'otsustama',
#  'alus',
#  'algama',
#  'neli',
#  'liige',
#  'üsna',
#  'endine',
#  'tegemine',
#  'tõmbama',
#  'täitma',
#  'vanem',
#  'tohtima',
#  'pakkuma',
#  'meri',
#  'märkama',
#  'süda',
#  'mets',
#  'hommik',
#  'selge',
#  'võõras',
#  'kuna',
#  'täiesti',
#  'õppima',
#  'tõesti',
#  'kõrval',
#  'lõpetama',
#  'vähemalt',
#  'suu',
#  'umbes',
#  'looma',
#  'tehtud',
#  'nimetama',
#  'seadus',
#  'alustama',
#  'lisama',
#  'esimees',
#  'puu',
#  'mäng',
#  'valima',
#  'kartma',
#  'teatama',
#  'ilus',
#  'liikuma',
#  'samm',
#  'tühi',
#  'eks',
#  'ajal',
#  'kuulama',
#  'kolmas',
#  'paluma',
#  'siia',
#  'uuesti',
#  'näima',
#  'president',
#  'nõnda',
#  'lootma',
#  'punane',
#  'abi',
#  'hing',
#  'poeg',
#  'veidi',
#  'sõda',
#  'pilt',
#  'arv',
#  'ilmuma',
#  'langema',
#  'valmis',
#  'mäletama',
#  'avama',
#  'sõber',
#  'kust',
#  'kohalik',
#  'vähem',
#  'ostma',
#  'sööma',
#  'eesmärk',
#  'leht',
#  'tõttu',
#  'kindlasti',
#  'vähe',
#  'sattuma',
#  'ruum',
#  'suvi',
#  'kümme',
#  'plaan',
#  'kõrge',
#  'sealt',
#  'loom',
#  'meeldima',
#  'tähtis',
#  'küla',
#  'tunnistama',
#  'kuidagi',
#  'praegune',
#  'sein',
#  'jooksma',
#  'avaldama',
#  'peal',
#  'tuhat',
#  'võitma',
#  'saksa',
#  'soovima',
#  'pöörama',
#  'keskmine',
#  'külm',
#  'otsa',
#  'öö',
#  'vaba',
#  'magama',
#  'muutma',
#  'sündima',
#  'antud',
#  'ajaleht',
#  'olev',
#  'ringi',
#  'hulgas',
#  'kohus',
#  'surm',
#  'naerma',
#  'õpetaja',
#  'kõrvale',
#  'sellepärast',
#  'uurima',
#  'leping',
#  'õhk',
#  'vahele',
#  'pisut',
#  'kõnelema',
#  'ehitama',
#  'korral',
#  'tegu',
#  'tuttav',
#  'hulk',
#  'tugev',
#  'piir',
#  'kaotama',
#  'seadma',
#  'heitma',
#  'tuul',
#  'hind',
#  'kaudu',
#  'puuduma',
#  'kevad',
#  'seisukoht',
#  'august',
#  'keha',
#  'otse',
#  'seega',
#  'vastus',
#  'pääsema',
#  'soe',
#  'muidu',
#  'm',
#  'päike',
#  'jne',
#  'ala',
#  'võit',
#  'õlg',
#  'puhas',
#  'järel',
#  'kivi',
#  'rootsi',
#  'direktor',
#  'j.',
#  'taevas',
#  'lahkuma',
#  'sundima',
#  'koguni',
#  'seni',
#  'võim',
#  'unustama',
#  'ligi',
#  'tütar',
#  'kirjanik',
#  'võitlus',
#  'rahu',
#  'i',
#  'müüma',
#  'seletama',
#  'hoone',
#  'kaua',
#  'protsent',
#  'materjal',
#  'külg',
#  'punkt',
#  'üksnes',
#  'ülikool',
#  'taha',
#  'soov',
#  'kunstnik',
#  'kostma',
#  'kohal',
#  'sügis',
#  'alt',
#  'rida',
#  'siit',
#  'kunst',
#  'ainus',
#  'koer',
#  'september',
#  'sees',
#  'juhtima',
#  'jaan',
#  'juhataja',
#  'noormees',
#  'ajalugu',
#  'laev',
#  'jooma',
#  'suruma',
#  'varsti',
#  'kirjandus',
#  'vorm',
#  'mil',
#  'huvitav',
#  'mai',
#  'õpilane',
#  'palk',
#  'minut',
#  'pank',
#  'muusika',
#  'kerge',
#  'selguma',
#  'korraga',
#  'armastama',
#  'veelgi',
#  'üksik',
#  'nimelt',
#  'tuli',
#  'halb',
#  'paik',
#  'viskama',
#  'saksamaa',
#  'teadmine',
#  'tarvis',
#  'asemel',
#  'kujutama',
#  'võrdlema',
#  'pealegi',
#  'ettepanek',
#  'voodi',
#  'mure',
#  'paber',
#  'määrama',
#  'hirm',
#  'peremees',
#  'saar',
#  'hall',
#  'tuntud',
#  'ühine',
#  'õnn',
#  'toetama',
#  'igaüks',
#  'lausuma',
#  'valgus',
#  'hindama',
#  'amet',
#  'm.',
#  'kõrgem',
#  'kõrv',
#  'tööline',
#  'jõgi',
#  'viga',
#  'lai',
#  'sõrm',
#  'sündmus',
#  'joon',
#  'armastus',
#  'noh',
#  'perekond',
#  'seesama',
#  'korter',
#  'laul',
#  'tükk',
#  'lõppema',
#  'liikumine',
#  'ilm',
#  'kuju',
#  'politsei',
#  'pere',
#  'lihtne',
#  'valmistama',
#  'balti',
#  'täitmine',
#  'talv',
#  'kuus',
#  'kukkuma',
#  'küllalt',
#  'muld',
#  'vend',
#  'mõju',
#  'juus',
#  'üksi',
#  'sekretär',
#  'hobune',
#  'vedama',
#  'tulevik',
#  'komme',
#  'toime',
#  'talu',
#  'valimine',
#  'omanik',
#  'leiduma',
#  'jüri',
#  'loodus',
#  'lühike',
#  'puutuma',
#  'sada',
#  'haige',
#  'tõsi',
#  'vajuma',
#  'keerama',
#  'rõõm',
#  'põhi',
#  'mõnikord',
#  'jagama',
#  'vaikima',
#  'ots',
#  'ääres',
#  'segama',
#  'külaline',
#  'veri',
#  'lükkama',
#  'üksteise',
#  'lendama',
#  'kirik',
#  'vari',
#  'paremini',
#  'klass',
#  'peeter',
#  'kaitsma',
#  'elanik',
#  'kaitse',
#  'kongress',
#  'põld',
#  'teadus',
#  'ammu',
#  'tõsine',
#  'õu',
#  'lugeja',
#  'märk',
#  'mõjuma',
#  'lootus',
#  'minister',
#  'tabama',
#  'tagant',
#  'kiire',
#  'vara',
#  'n',
#  'pärnu',
#  'nurk',
#  'asutus',
#  'pealt',
#  'lind',
#  'rind',
#  'püsti',
#  'niisama',
#  'saal',
#  'e.',
#  'vaim',
#  'läti',
#  'kallas',
#  'kodanik',
#  'kahju',
#  'kõne',
#  'naeratama',
#  'põrand',
#  'kasu',
#  'riie',
#  'tähtsus',
#  'lõikama',
#  'tänu',
#  'kasvatama',
#  'arst',
#  'saatus',
#  'abil',
#  'mägi',
#  'aed',
#  'teade',
#  'piim',
#  'masin',
#  'õpetama',
#  'madal',
#  'lumi',
#  'hüüdma',
#  'teineteise',
#  'komisjon',
#  'viibima',
#  'p',
#  'vabadus',
#  'teenima',
#  'nina',
#  'ah',
#  'surema',
#  'elav',
#  'vaevalt',
#  'kael',
#  'millal',
#  'turg',
#  'hulka',
#  'tänavu',
#  'laulma',
#  'number',
#  'käik',
#  'käesolev',
#  'koosolek',
#  'näitus',
#  'h.',
#  'teatud',
#  'vahtima',
#  'suurus',
#  'vili',
#  'soovitama',
#  'mitmesugune',
#  'vahe',
#  'väärtus',
#  'õieti',
#  'tagajärg',
#  'pikem',
#  'julgema',
#  'poolest',
#  'kallis',
#  'vaikne',
#  'köök',
#  'pime',
#  'klaas',
#  'vahetama',
#  'mälestus',
#  'juuli',
#  'roheline',
#  'tihti',
#  'õde',
#  'osakond',
#  'värv',
#  'värav',
#  'tõde',
#  'e',
#  'kuulutama',
#  'tervis',
#  'hool',
#  'pind',
#  'lehm',
#  'saadud',
#  'imelik',
#  'missugune',
#  'raskus',
#  'kõndima',
#  'koguma',
#  'avalik',
#  'sisu',
#  'mari',
#  'kordama',
#  'seitse',
#  'järv',
#  'vähene',
#  'senine',
#  'nutma',
#  'tasku',
#  'kõlama',
#  'üliõpilane',
#  'tähtsam',
#  'kaup',
#  'nõu',
#  'kurat',
#  'surnud',
#  'protsess',
#  'kiskuma',
#  'nimetatud',
#  'ronima',
#  't',
#  'keelama',
#  'trepp',
#  'kippuma',
#  'tume',
#  'seekord',
#  'tasuma',
#  'ehitus',
#  'teisiti',
#  'homme',
#  'meister',
#  'i.',
#  'detsember',
#  'nahk',
#  'parandama',
#  'valitsema',
#  'põhjal',
#  'juhan',
#  'rong',
#  'väljas',
#  'lill',
#  'seas',
#  'sugugi',
#  'sõit',
#  'pistma',
#  'saamine',
#  'tõsiselt',
#  'summa',
#  'harjuma',
#  'r.',
#  'hiina',
#  'noorem',
#  'võitlema',
#  'suurendama',
#  'kestma',
#  'kannatama',
#  'pärima',
#  'k.',
#  'katus',
#  'poola',
#  'l',
#  'v',
#  'kätte',
#  'katma',
#  'murdma',
#  'ühtlasi',
#  'õnnelik',
#  'häda',
#  'narva',
#  'külge',
#  'sügav',
#  'ärkama',
#  'kaheksa',
#  'tänane',
#  'imestama',
#  'ajakirjandus',
#  'täielik',
#  'raamatukogu',
#  'aprill',
#  'lähedal',
#  'katsuma',
#  'vaikus',
#  'kahjuks',
#  'pudel',
#  'ükskõik',
#  'korralik',
#  'varjama',
#  'läbirääkimine',
#  'viin',
#  'vastane',
#  'hoolimata',
#  'kaunis',
#  'haigus',
#  'kahtlus',
#  'sakslane',
#  'toon',
#  'lõuna',
#  'vägi',
#  'selts',
#  'juhatus',
#  'nr',
#  'kitsas',
#  'käest',
#  'leppima',
#  'katse',
#  'ümbrus',
#  'iseloom',
#  'sinine',
#  'kaarel',
#  'hüppama',
#  'kauge',
#  'kuluma',
#  'hammas',
#  'öösel',
#  'vahest',
#  'korraks',
#  'rikkuma',
#  'karjuma',
#  'ehitamine',
#  'värske',
#  'eemale',
#  'vahelt',
#  'laiali',
#  'seltsimees',
#  'saadik',
#  'põlema',
#  'r',
#  'pealinn',
#  'liha',
#  'leib',
#  'ilmunud',
#  'vald',
#  'lause',
#  'l.',
#  'eestimaa',
#  'nimel',
#  'kakskümmend',
#  'kodumaa',
#  'tapma',
#  'keskel',
#  'aimama',
#  'pehme',
#  'täht',
#  'nähtus',
#  'kõrgus',
#  'järsku',
#  'harva',
#  'hirmus',
#  'kauplus',
#  'kaugel',
#  'terav',
#  'ohvitser',
#  'maantee',
#  'sadam',
#  'teatav',
#  'kiitma',
#  'huul',
#  'puudus',
#  'püha',
#  'jutustama',
#  'võimalikult',
#  'hiljuti',
#  'jaak',
#  'mujal',
#  'professor',
#  'kuningas',
#  'saak',
#  'lähenema',
#  'silmitsema',
#  'koor',
#  'k',
#  'tool',
#  'prantsuse',
#  'kuum',
#  'kiirus',
#  'rada',
#  'käsk',
#  'siduma',
#  'kõva',
#  'laine',
#  'paul',
#  'n.',
#  'teel',
#  'pisike',
#  'ametlik',
#  'vihm',
#  'jälg',
#  'vaev',
#  'määratud',
#  'kaugele',
#  'kontsert',
#  'loodud',
#  'inglise',
#  'äratama',
#  'rahulikult',
#  'paljas',
#  'kuri',
#  'karl',
#  'juurest',
#  'põgenema',
#  'päästma',
#  'neljas',
#  'sirutama',
#  'omadus',
#  'tegelane',
#  'rakvere',
#  'tulevane',
#  'pühapäev',
#  'lähem',
#  'mõistus',
#  'tuletama',
#  'peetud',
#  'toimetus',
#  'loomulik',
#  'puhkama',
#  'siinne',
#  'süüdi',
#  'omandama',
#  'liiv',
#  'tähele',
#  'uhke',
#  'tõstmine',
#  'põlv',
#  'raud',
#  'suits',
#  'haridus',
#  'käes',
#  'kuiv',
#  'igapäevane',
#  'rahul',
#  'märts',
#  'komitee',
#  'abinõu',
#  'hoog',
#  'viimaks',
#  'vaenlane',
#  'väsinud',
#  'peagi',
#  'pihk',
#  'vang',
#  'tungima',
#  'riia',
#  'nimekiri',
#  'ühendus',
#  'helsingi',
#  'tutvustama',
#  'kurb',
#  'kuulus',
#  'jaapan',
#  'laupäev',
#  'ähvardama',
#  'avatud',
#  'tänama',
#  'muretsema',
#  's.',
#  'sõnama',
#  'vaidlema',
#  'inglismaa',
#  'ulatama',
#  'tulev',
#  ...]

# %%
vecs = [[None] * len(decades) for i in range(len(all_words))]

# %%
for i, word in enumerate(all_words):
    for j, decade in enumerate(decades):
        vecs[i][j] = list(aligned_models[decade].wv[word])

# %%
saveable = {'E': vecs,
    "w": all_words,
    "d": decades}

with open(f'{MODEL_DIR}/word2vec_a_1890-1990_diachronic.pickle', 'wb') as handle:
    pickle.dump(saveable, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open(f'{MODEL_DIR}/word2vec_a_1890-1990_diachronic.pickle', 'rb') as handle:
    b = pickle.load(handle)
    
print(saveable == b)
# Out:
# True

# %% [markdown]
# ## SVD

# %%
MODEL_DIR = "./models/svd"

# %%
aligned_svd_models
# Out:
# {1890: <svd2vec.core.svd2vec at 0x11e58d86b20>,
#  1900: <svd2vec.core.svd2vec at 0x11e58d86340>,
#  1910: <svd2vec.core.svd2vec at 0x11e58d867f0>,
#  1930: <svd2vec.core.svd2vec at 0x11e58d869d0>,
#  1950: <svd2vec.core.svd2vec at 0x11e58d86af0>,
#  1960: <svd2vec.core.svd2vec at 0x11e58d86460>,
#  1970: <svd2vec.core.svd2vec at 0x11e58d86580>,
#  1980: <svd2vec.core.svd2vec at 0x11e58d86430>,
#  1990: <svd2vec.core.svd2vec at 0x11e58d86ca0>}

# %%
all_words = list(aligned_svd_models[ref_year].words)
all_words
# Out:
# ['olema',
#  'ja',
#  'tema',
#  'see',
#  'ei',
#  'mina',
#  'kui',
#  'et',
#  'mis',
#  'ka',
#  'oma',
#  'aga',
#  'ning',
#  'saama',
#  'tulema',
#  'nii',
#  'ise',
#  'pidama',
#  'kes',
#  'aasta',
#  'või',
#  'siis',
#  'üks',
#  'sina',
#  'minema',
#  'võima',
#  'tegema',
#  'teine',
#  'nagu',
#  'ütlema',
#  'aeg',
#  'võtma',
#  'kõik',
#  'veel',
#  'mees',
#  'juba',
#  'suur',
#  'eesti',
#  'inimene',
#  'ära',
#  'jääma',
#  'teadma',
#  'välja',
#  'kas',
#  'kuid',
#  'andma',
#  'nägema',
#  'hakkama',
#  'mitte',
#  'üle',
#  'miski',
#  'töö',
#  'nüüd',
#  'palju',
#  'kord',
#  'vaid',
#  'iga',
#  'uus',
#  'mõni',
#  'siin',
#  'sest',
#  'küll',
#  'ju',
#  'kaks',
#  'tahtma',
#  'kus',
#  'enam',
#  'väga',
#  'panema',
#  'pärast',
#  'vaatama',
#  'ainult',
#  'ikka',
#  'käima',
#  'seal',
#  'esimene',
#  'rääkima',
#  'vastu',
#  'tundma',
#  'ega',
#  'päev',
#  'hea',
#  'kuidas',
#  'eest',
#  'peale',
#  'käsi',
#  'naine',
#  'tagasi',
#  'asi',
#  'a',
#  'silm',
#  'enne',
#  'kõige',
#  'osa',
#  'viimane',
#  'sama',
#  'sõna',
#  'mõtlema',
#  'elu',
#  'mingi',
#  'kogu',
#  'rohkem',
#  'maa',
#  'tallinn',
#  'jõudma',
#  'laps',
#  'leidma',
#  'ette',
#  'arvama',
#  'mitu',
#  'kolm',
#  'poole',
#  'pool',
#  'elama',
#  'istuma',
#  'tooma',
#  'koos',
#  'seisma',
#  'all',
#  'jätma',
#  'ema',
#  'kohta',
#  'läbi',
#  'linn',
#  'maja',
#  'kuulma',
#  'just',
#  'ees',
#  'praegu',
#  'isegi',
#  'keegi',
#  'pea',
#  'mõte',
#  'tee',
#  'kuni',
#  'suurem',
#  'oskama',
#  'noor',
#  'edasi',
#  'riik',
#  'poolt',
#  'vaja',
#  'viis',
#  'vahel',
#  'niisugune',
#  'jalg',
#  'laskma',
#  'juht',
#  'koht',
#  'siiski',
#  'küsima',
#  'kindel',
#  'väike',
#  'suutma',
#  'valge',
#  'lõpp',
#  'püüdma',
#  'viima',
#  'vana',
#  'kodu',
#  'kohe',
#  'lugema',
#  'alles',
#  'kirjutama',
#  'üles',
#  'miks',
#  'juurde',
#  'muu',
#  'pikk',
#  'uks',
#  'ehk',
#  'valitsus',
#  'keel',
#  'raske',
#  'algus',
#  'kaasa',
#  'poiss',
#  'hästi',
#  'muutuma',
#  'vesi',
#  'võimalik',
#  'kokku',
#  'lööma',
#  'alla',
#  'alus',
#  'vastama',
#  'alati',
#  'ootama',
#  'hiljem',
#  'küsimus',
#  'maailm',
#  'tartu',
#  'tegevus',
#  'rahvas',
#  'nõudma',
#  'hoopis',
#  'isa',
#  'hääl',
#  'astuma',
#  'muidugi',
#  'tuba',
#  'nägu',
#  'raha',
#  'kinni',
#  'mööda',
#  'näitama',
#  'hoidma',
#  'maha',
#  'tekkima',
#  'sisse',
#  'jõud',
#  'juures',
#  'ometi',
#  'lubama',
#  'kuigi',
#  'miljon',
#  'asuma',
#  'algama',
#  'taga',
#  'aitama',
#  'töötama',
#  'sõitma',
#  'ümber',
#  'jooksul',
#  'tohtima',
#  'parem',
#  'peaaegu',
#  'liiga',
#  'kunagi',
#  'jälle',
#  'lahti',
#  'aru',
#  'mõlema',
#  'paar',
#  'nimi',
#  'ajama',
#  'kiri',
#  'järele',
#  'uskuma',
#  'jutt',
#  'meel',
#  'moskva',
#  'täis',
#  'üsna',
#  'õige',
#  'saatma',
#  'ilma',
#  'järgmine',
#  'puhul',
#  'mõistma',
#  'raamat',
#  'täiesti',
#  'kool',
#  'tegemine',
#  'jaoks',
#  'must',
#  'ilmuma',
#  'too',
#  'tüdruk',
#  'nõnda',
#  'jah',
#  'kuhu',
#  'kell',
#  'tänav',
#  'ruum',
#  'tähendama',
#  'kutsuma',
#  'ülesanne',
#  'otsima',
#  'pilk',
#  'meri',
#  'kaduma',
#  'päris',
#  'täitma',
#  'sinna',
#  'tõusma',
#  'soome',
#  'hulk',
#  '',
#  'terve',
#  'laud',
#  'tehtud',
#  'mängima',
#  'maksma',
#  'neli',
#  'endine',
#  'looma',
#  'umbes',
#  'kõrval',
#  'ettevõte',
#  'juhtuma',
#  'seadus',
#  'tunnistama',
#  'poeg',
#  'tõstma',
#  'president',
#  'tõmbama',
#  'langema',
#  'vist',
#  'vähemalt',
#  'liige',
#  'hing',
#  'tund',
#  'õigus',
#  'kandma',
#  'alustama',
#  'lugu',
#  'kasvama',
#  'kümme',
#  'tõttu',
#  'selg',
#  'lootma',
#  'täna',
#  'kuu',
#  'ringi',
#  'valima',
#  'kartma',
#  'õhtu',
#  'kuna',
#  'õppima',
#  'partei',
#  'otsus',
#  'lihtsalt',
#  'punane',
#  'varem',
#  'lisama',
#  'näima',
#  'vanem',
#  'kuuluma',
#  'pilt',
#  'aken',
#  'kohalik',
#  'eks',
#  'sõda',
#  'seisukoht',
#  'mets',
#  'kroon',
#  'avaldama',
#  'a.',
#  'nimetama',
#  'sattuma',
#  'tuttav',
#  'lõpetama',
#  'mäng',
#  'kõrge',
#  'ajal',
#  'otsustama',
#  'peal',
#  'august',
#  'võõras',
#  'unustama',
#  'otse',
#  'seega',
#  'põhjus',
#  'tõesti',
#  'ostma',
#  'vabariik',
#  'nädal',
#  'sein',
#  'sealt',
#  'puu',
#  'leiduma',
#  'eesmärk',
#  'kohus',
#  'saksa',
#  'hommik',
#  'märkama',
#  'pakkuma',
#  'meeldima',
#  'arv',
#  'õpetaja',
#  'soov',
#  'uuesti',
#  'esimees',
#  'valmis',
#  'selge',
#  'teater',
#  'vähe',
#  'kolmas',
#  'kõrvale',
#  'kõnelema',
#  'tühi',
#  'siia',
#  'samm',
#  'pöörduma',
#  'õhk',
#  'liikuma',
#  'teatama',
#  'jooksma',
#  'otsa',
#  'pöörama',
#  'suvi',
#  'kirjandus',
#  'korral',
#  'kevad',
#  'tähtis',
#  'seni',
#  'taevas',
#  'sõber',
#  'leping',
#  'magama',
#  'paistma',
#  'kaotama',
#  'koguni',
#  'kaudu',
#  'paluma',
#  'i',
#  'kindlasti',
#  'alt',
#  'võim',
#  'jooma',
#  'uurima',
#  'mäletama',
#  'sündima',
#  'kostma',
#  'hulgas',
#  'tegu',
#  'ligi',
#  'olev',
#  'puuduma',
#  'loom',
#  'vorm',
#  'külm',
#  'üksnes',
#  'materjal',
#  'avama',
#  'leht',
#  'veidi',
#  'm',
#  'ajalugu',
#  'kinnitama',
#  'mil',
#  'tugev',
#  'kuulama',
#  'vähem',
#  'võrdlema',
#  'enamasti',
#  'keha',
#  'seadma',
#  'ajaleht',
#  'protsent',
#  'tuhat',
#  'suu',
#  'tuntud',
#  'läti',
#  'sööma',
#  'küla',
#  'väiksem',
#  'vaba',
#  'saksamaa',
#  'üksik',
#  'kasvatama',
#  'jüri',
#  'jne',
#  'toime',
#  'järel',
#  'sundima',
#  'küllap',
#  'soe',
#  'müüma',
#  'sügis',
#  'peremees',
#  'pisut',
#  'rootsi',
#  'süda',
#  'praegune',
#  'korraldama',
#  'klass',
#  'heitma',
#  'lõpuks',
#  'armastus',
#  'kohal',
#  'kunstnik',
#  'võit',
#  'märkima',
#  'kerge',
#  'vahele',
#  'tõepoolest',
#  'sellepärast',
#  'laev',
#  'keskmine',
#  'lahkuma',
#  'perekond',
#  'rida',
#  'komme',
#  'joon',
#  'palk',
#  'kuju',
#  'lausa',
#  'piir',
#  'asemel',
#  'nimelt',
#  'põhi',
#  'paik',
#  'vastus',
#  'tütar',
#  'hoone',
#  'ilus',
#  'liikumine',
#  'veelgi',
#  'amet',
#  'vedama',
#  'loodus',
#  'õpilane',
#  'hind',
#  'korter',
#  'kujutama',
#  'lükkama',
#  'paremini',
#  'ala',
#  'päike',
#  'muutma',
#  'kuus',
#  'direktor',
#  'saar',
#  'abi',
#  'plaan',
#  'algul',
#  'vabadus',
#  'soovima',
#  'rubla',
#  'huvitav',
#  'hirm',
#  'ehitama',
#  'korraga',
#  'tarvis',
#  'kõrv',
#  'puhas',
#  'õpetama',
#  'lihtne',
#  'muusika',
#  'tervis',
#  'eestlane',
#  'tõsi',
#  'vend',
#  'mägi',
#  'teadus',
#  's',
#  'vaikne',
#  'koer',
#  'rahu',
#  'j.',
#  'antud',
#  'haarama',
#  'avalik',
#  'ettepanek',
#  'õlg',
#  'juhtima',
#  'kuidagi',
#  'kohale',
#  'seepärast',
#  'taha',
#  'pääsema',
#  'muld',
#  'viskama',
#  'toetama',
#  'võimalikult',
#  'tuul',
#  'vara',
#  'tänu',
#  'ühine',
#  'tähtsus',
#  'lendama',
#  'kaitsma',
#  'soovitama',
#  'lugeja',
#  'kael',
#  'suruma',
#  'võitlus',
#  'tabama',
#  'surm',
#  'jaan',
#  'sündmus',
#  'kunst',
#  'kasu',
#  'sada',
#  'paber',
#  'punkt',
#  'puutuma',
#  'jumal',
#  'kivi',
#  'naerma',
#  'kasv',
#  'ots',
#  'vähene',
#  'võitma',
#  'põrand',
#  'talu',
#  'varsti',
#  'taim',
#  'keerama',
#  'tagant',
#  'kahju',
#  'programm',
#  'viga',
#  'juuli',
#  'üksteise',
#  'juhataja',
#  'koguma',
#  'öö',
#  'minister',
#  'number',
#  'tuli',
#  'lausuma',
#  'muidu',
#  'kirjanik',
#  'ülikool',
#  'valimine',
#  'kust',
#  'september',
#  'piim',
#  'viibima',
#  'elanik',
#  'uurimine',
#  'abil',
#  'lind',
#  'n',
#  'külaline',
#  'ainus',
#  'pank',
#  'juus',
#  'teatud',
#  'põld',
#  'teineteise',
#  'õieti',
#  'poolest',
#  'kiiresti',
#  'sinine',
#  'suurus',
#  'küllalt',
#  'pere',
#  'kallas',
#  'mõjuma',
#  'sees',
#  'siit',
#  'mõnikord',
#  'uni',
#  'üksi',
#  'järgnema',
#  'suurendama',
#  'natuke',
#  'kaua',
#  'kallis',
#  'tõde',
#  'segama',
#  'kaitse',
#  'vari',
#  'mälestus',
#  'leib',
#  'lai',
#  'nimetatud',
#  'tõsine',
#  'saadud',
#  'avaldus',
#  'pime',
#  'ammu',
#  'täitmine',
#  'tulevik',
#  'õu',
#  'arutama',
#  'hall',
#  'ilm',
#  'seletama',
#  'mure',
#  'mitmesugune',
#  'lõikama',
#  'kodanik',
#  'talv',
#  'summa',
#  'vaevalt',
#  'märk',
#  'juuni',
#  'jagama',
#  'nurk',
#  'seitse',
#  'järv',
#  'kõndima',
#  'nr',
#  'nutma',
#  'tükk',
#  'hobune',
#  'sisu',
#  'kaup',
#  'selguma',
#  'hüüdma',
#  'iseenese',
#  'seekord',
#  'lääs',
#  'sakslane',
#  'ääres',
#  'haige',
#  'tume',
#  'pealinn',
#  'teisiti',
#  'mai',
#  'toon',
#  'pind',
#  'lõppema',
#  'lumi',
#  'asutus',
#  'voodi',
#  'värav',
#  'aina',
#  'vahetama',
#  'säärane',
#  'vaim',
#  'kiire',
#  'komisjon',
#  'igaüks',
#  'laul',
#  'mari',
#  'koosolek',
#  'klaas',
#  'hulka',
#  'november',
#  'edu',
#  'noormees',
#  'lühike',
#  'õnn',
#  'seesama',
#  'jõgi',
#  'halb',
#  'minut',
#  'veri',
#  'pudel',
#  'kirik',
#  'saal',
#  'millal',
#  'balti',
#  'nõue',
#  'mõju',
#  'saatus',
#  'politsei',
#  'nina',
#  'raskus',
#  'kukkuma',
#  'külg',
#  'vaikima',
#  'nõu',
#  'tihti',
#  'rind',
#  'mõis',
#  'm.',
#  'arst',
#  'kaunis',
#  'pehme',
#  'kuum',
#  'valgus',
#  'laulma',
#  'kõlama',
#  'pealt',
#  'kumbki',
#  'aed',
#  'r',
#  'sügav',
#  'sõrm',
#  'toit',
#  'kuulutama',
#  'puudutama',
#  'keelama',
#  'kõne',
#  'väärtus',
#  'vanamees',
#  'korraks',
#  'trepp',
#  'teenima',
#  'täielikult',
#  'valitsema',
#  'näitus',
#  'hindama',
#  'narva',
#  'ah',
#  'äratama',
#  'tagajärg',
#  'vili',
#  'surnud',
#  'abinõu',
#  'armastama',
#  'vahtima',
#  'tänane',
#  'kusagil',
#  'õis',
#  'juhatus',
#  'roheline',
#  'vastane',
#  'määrama',
#  'rõõm',
#  'juhan',
#  'kala',
#  'katus',
#  'katma',
#  'saamine',
#  'senine',
#  'kongress',
#  'omanik',
#  'kott',
#  'g',
#  'lootus',
#  'liha',
#  'e',
#  'võimatu',
#  'köök',
#  'vahelt',
#  'tasku',
#  'kiirus',
#  'ühtlasi',
#  'selts',
#  'karl',
#  'hoolimata',
#  'nähtus',
#  'detsember',
#  'pärima',
#  'ükskõik',
#  'vaene',
#  'kõrgem',
#  'tööline',
#  'side',
#  'vaatamata',
#  'igatahes',
#  'aprill',
#  'b',
#  'vanaema',
#  'kiskuma',
#  'madal',
#  'tähendus',
#  'osakond',
#  'elav',
#  'noorem',
#  'püsti',
#  'vahe',
#  'pikem',
#  'tõsiselt',
#  'haigus',
#  'paul',
#  'seas',
#  'kuritegu',
#  'iseloom',
#  'määratud',
#  'tähtsam',
#  'hool',
#  'ümbrus',
#  'k',
#  'kaugel',
#  'kaheksa',
#  'kippuma',
#  'peeter',
#  'tihe',
#  'kauge',
#  'tõlge',
#  'kurat',
#  'teade',
#  'parandama',
#  'riie',
#  'kurb',
#  'liik',
#  'professor',
#  'värv',
#  'sõit',
#  'noh',
#  'põlema',
#  'valmistama',
#  'jaak',
#  'hammas',
#  'kartul',
#  'ilmunud',
#  'ärkama',
#  'põhjal',
#  'valu',
#  'paks',
#  'viin',
#  'pealegi',
#  'katsuma',
#  'lähenema',
#  'liiv',
#  'kiitma',
#  'tungima',
#  'kätte',
#  'ajalooline',
#  'imelik',
#  'naeratama',
#  'v',
#  'imestama',
#  'ring',
#  'kaarel',
#  'ajakirjandus',
#  'r.',
#  'oh',
#  'dollar',
#  'teadmine',
#  'kerkima',
#  'õnnelik',
#  'masin',
#  't',
#  'tutvustama',
#  'märts',
#  'lehm',
#  'rippuma',
#  'kahtlema',
#  'ii',
#  'harjuma',
#  'julgema',
#  'eestimaa',
#  'abielu',
#  'muna',
#  'kodune',
#  'tulevane',
#  'rikkuma',
#  'vajuma',
#  'kitsas',
#  'loomulik',
#  'varjama',
#  'vahest',
#  'ehitus',
#  'tantsima',
#  'silmitsema',
#  'kannatama',
#  'luba',
#  'omadus',
#  'ahi',
#  'e.',
#  'tegelane',
#  'kass',
#  'korjama',
#  'kuulus',
#  'ronima',
#  'niisama',
#  'jutustama',
#  'pistma',
#  'kahjuks',
#  'missugune',
#  'nahk',
#  'j',
#  'p',
#  'iseseisev',
#  'inglise',
#  'lähedal',
#  'surema',
#  'tool',
#  'mõistus',
#  'kuiv',
#  'prantsuse',
#  'käesolev',
#  'turg',
#  'no',
#  'ungari',
#  'kollane',
#  'ainuke',
#  'väljas',
#  'korraldus',
#  'k.',
#  'lill',
#  'tasu',
#  'serv',
#  'kaal',
#  'kõvasti',
#  'vald',
#  'puudus',
#  'korralik',
#  'peagi',
#  'läbirääkimine',
#  'hiljuti',
#  'rada',
#  'etendus',
#  'tulev',
#  'h.',
#  'naer',
#  'muretsema',
#  'kestma',
#  'saadik',
#  'parandamine',
#  'takistama',
#  'vaheline',
#  'vähenema',
#  'sugugi',
#  'leppima',
#  'vaenlane',
#  'järeldus',
#  'perenaine',
#  'pärnu',
#  'märg',
#  'neljas',
#  'teatav',
#  'hele',
#  'eemal',
#  'harva',
#  'külge',
#  'hirmus',
#  'dokument',
#  'tänavu',
#  'lõuna',
#  'protsess',
#  'lause',
#  'inglismaa',
#  'lagi',
#  'kaugele',
#  'kordama',
#  'peetud',
#  'hiina',
#  'käik',
#  'täielik',
#  ...]

# %%
aligned_svd_models[ref_year].vocabulary
# Out:
# {'olema': 0,
#  'ja': 1,
#  'tema': 2,
#  'see': 3,
#  'ei': 4,
#  'mina': 5,
#  'kui': 6,
#  'et': 7,
#  'mis': 8,
#  'ka': 9,
#  'oma': 10,
#  'aga': 11,
#  'ning': 12,
#  'saama': 13,
#  'tulema': 14,
#  'nii': 15,
#  'ise': 16,
#  'pidama': 17,
#  'kes': 18,
#  'aasta': 19,
#  'või': 20,
#  'siis': 21,
#  'üks': 22,
#  'sina': 23,
#  'minema': 24,
#  'võima': 25,
#  'tegema': 26,
#  'teine': 27,
#  'nagu': 28,
#  'ütlema': 29,
#  'aeg': 30,
#  'võtma': 31,
#  'kõik': 32,
#  'veel': 33,
#  'mees': 34,
#  'juba': 35,
#  'suur': 36,
#  'eesti': 37,
#  'inimene': 38,
#  'ära': 39,
#  'jääma': 40,
#  'teadma': 41,
#  'välja': 42,
#  'kas': 43,
#  'kuid': 44,
#  'andma': 45,
#  'nägema': 46,
#  'hakkama': 47,
#  'mitte': 48,
#  'üle': 49,
#  'miski': 50,
#  'töö': 51,
#  'nüüd': 52,
#  'palju': 53,
#  'kord': 54,
#  'vaid': 55,
#  'iga': 56,
#  'uus': 57,
#  'mõni': 58,
#  'siin': 59,
#  'sest': 60,
#  'küll': 61,
#  'ju': 62,
#  'kaks': 63,
#  'tahtma': 64,
#  'kus': 65,
#  'enam': 66,
#  'väga': 67,
#  'panema': 68,
#  'pärast': 69,
#  'vaatama': 70,
#  'ainult': 71,
#  'ikka': 72,
#  'käima': 73,
#  'seal': 74,
#  'esimene': 75,
#  'rääkima': 76,
#  'vastu': 77,
#  'tundma': 78,
#  'ega': 79,
#  'päev': 80,
#  'hea': 81,
#  'kuidas': 82,
#  'eest': 83,
#  'peale': 84,
#  'käsi': 85,
#  'naine': 86,
#  'tagasi': 87,
#  'asi': 88,
#  'a': 89,
#  'silm': 90,
#  'enne': 91,
#  'kõige': 92,
#  'osa': 93,
#  'viimane': 94,
#  'sama': 95,
#  'sõna': 96,
#  'mõtlema': 97,
#  'elu': 98,
#  'mingi': 99,
#  'kogu': 100,
#  'rohkem': 101,
#  'maa': 102,
#  'tallinn': 103,
#  'jõudma': 104,
#  'laps': 105,
#  'leidma': 106,
#  'ette': 107,
#  'arvama': 108,
#  'mitu': 109,
#  'kolm': 110,
#  'poole': 111,
#  'pool': 112,
#  'elama': 113,
#  'istuma': 114,
#  'tooma': 115,
#  'koos': 116,
#  'seisma': 117,
#  'all': 118,
#  'jätma': 119,
#  'ema': 120,
#  'kohta': 121,
#  'läbi': 122,
#  'linn': 123,
#  'maja': 124,
#  'kuulma': 125,
#  'just': 126,
#  'ees': 127,
#  'praegu': 128,
#  'isegi': 129,
#  'keegi': 130,
#  'pea': 131,
#  'mõte': 132,
#  'tee': 133,
#  'kuni': 134,
#  'suurem': 135,
#  'oskama': 136,
#  'noor': 137,
#  'edasi': 138,
#  'riik': 139,
#  'poolt': 140,
#  'vaja': 141,
#  'viis': 142,
#  'vahel': 143,
#  'niisugune': 144,
#  'jalg': 145,
#  'laskma': 146,
#  'juht': 147,
#  'koht': 148,
#  'siiski': 149,
#  'küsima': 150,
#  'kindel': 151,
#  'väike': 152,
#  'suutma': 153,
#  'valge': 154,
#  'lõpp': 155,
#  'püüdma': 156,
#  'viima': 157,
#  'vana': 158,
#  'kodu': 159,
#  'kohe': 160,
#  'lugema': 161,
#  'alles': 162,
#  'kirjutama': 163,
#  'üles': 164,
#  'miks': 165,
#  'juurde': 166,
#  'muu': 167,
#  'pikk': 168,
#  'uks': 169,
#  'ehk': 170,
#  'valitsus': 171,
#  'keel': 172,
#  'raske': 173,
#  'algus': 174,
#  'kaasa': 175,
#  'poiss': 176,
#  'hästi': 177,
#  'muutuma': 178,
#  'vesi': 179,
#  'võimalik': 180,
#  'kokku': 181,
#  'lööma': 182,
#  'alla': 183,
#  'alus': 184,
#  'vastama': 185,
#  'alati': 186,
#  'ootama': 187,
#  'hiljem': 188,
#  'küsimus': 189,
#  'maailm': 190,
#  'tartu': 191,
#  'tegevus': 192,
#  'rahvas': 193,
#  'nõudma': 194,
#  'hoopis': 195,
#  'isa': 196,
#  'hääl': 197,
#  'astuma': 198,
#  'muidugi': 199,
#  'tuba': 200,
#  'nägu': 201,
#  'raha': 202,
#  'kinni': 203,
#  'mööda': 204,
#  'näitama': 205,
#  'hoidma': 206,
#  'maha': 207,
#  'tekkima': 208,
#  'sisse': 209,
#  'jõud': 210,
#  'juures': 211,
#  'ometi': 212,
#  'lubama': 213,
#  'kuigi': 214,
#  'miljon': 215,
#  'asuma': 216,
#  'algama': 217,
#  'taga': 218,
#  'aitama': 219,
#  'töötama': 220,
#  'sõitma': 221,
#  'ümber': 222,
#  'jooksul': 223,
#  'tohtima': 224,
#  'parem': 225,
#  'peaaegu': 226,
#  'liiga': 227,
#  'kunagi': 228,
#  'jälle': 229,
#  'lahti': 230,
#  'aru': 231,
#  'mõlema': 232,
#  'paar': 233,
#  'nimi': 234,
#  'ajama': 235,
#  'kiri': 236,
#  'järele': 237,
#  'uskuma': 238,
#  'jutt': 239,
#  'meel': 240,
#  'moskva': 241,
#  'täis': 242,
#  'üsna': 243,
#  'õige': 244,
#  'saatma': 245,
#  'ilma': 246,
#  'järgmine': 247,
#  'puhul': 248,
#  'mõistma': 249,
#  'raamat': 250,
#  'täiesti': 251,
#  'kool': 252,
#  'tegemine': 253,
#  'jaoks': 254,
#  'must': 255,
#  'ilmuma': 256,
#  'too': 257,
#  'tüdruk': 258,
#  'nõnda': 259,
#  'jah': 260,
#  'kuhu': 261,
#  'kell': 262,
#  'tänav': 263,
#  'ruum': 264,
#  'tähendama': 265,
#  'kutsuma': 266,
#  'ülesanne': 267,
#  'otsima': 268,
#  'pilk': 269,
#  'meri': 270,
#  'kaduma': 271,
#  'päris': 272,
#  'täitma': 273,
#  'sinna': 274,
#  'tõusma': 275,
#  'soome': 276,
#  'hulk': 277,
#  '': 278,
#  'terve': 279,
#  'laud': 280,
#  'tehtud': 281,
#  'mängima': 282,
#  'maksma': 283,
#  'neli': 284,
#  'endine': 285,
#  'looma': 286,
#  'umbes': 287,
#  'kõrval': 288,
#  'ettevõte': 289,
#  'juhtuma': 290,
#  'seadus': 291,
#  'tunnistama': 292,
#  'poeg': 293,
#  'tõstma': 294,
#  'president': 295,
#  'tõmbama': 296,
#  'langema': 297,
#  'vist': 298,
#  'vähemalt': 299,
#  'liige': 300,
#  'hing': 301,
#  'tund': 302,
#  'õigus': 303,
#  'kandma': 304,
#  'alustama': 305,
#  'lugu': 306,
#  'kasvama': 307,
#  'kümme': 308,
#  'tõttu': 309,
#  'selg': 310,
#  'lootma': 311,
#  'täna': 312,
#  'kuu': 313,
#  'ringi': 314,
#  'valima': 315,
#  'kartma': 316,
#  'õhtu': 317,
#  'kuna': 318,
#  'õppima': 319,
#  'partei': 320,
#  'otsus': 321,
#  'lihtsalt': 322,
#  'punane': 323,
#  'varem': 324,
#  'lisama': 325,
#  'näima': 326,
#  'vanem': 327,
#  'kuuluma': 328,
#  'pilt': 329,
#  'aken': 330,
#  'kohalik': 331,
#  'eks': 332,
#  'sõda': 333,
#  'seisukoht': 334,
#  'mets': 335,
#  'kroon': 336,
#  'avaldama': 337,
#  'a.': 338,
#  'nimetama': 339,
#  'sattuma': 340,
#  'tuttav': 341,
#  'lõpetama': 342,
#  'mäng': 343,
#  'kõrge': 344,
#  'ajal': 345,
#  'otsustama': 346,
#  'peal': 347,
#  'august': 348,
#  'võõras': 349,
#  'unustama': 350,
#  'otse': 351,
#  'seega': 352,
#  'põhjus': 353,
#  'tõesti': 354,
#  'ostma': 355,
#  'vabariik': 356,
#  'nädal': 357,
#  'sein': 358,
#  'sealt': 359,
#  'puu': 360,
#  'leiduma': 361,
#  'eesmärk': 362,
#  'kohus': 363,
#  'saksa': 364,
#  'hommik': 365,
#  'märkama': 366,
#  'pakkuma': 367,
#  'meeldima': 368,
#  'arv': 369,
#  'õpetaja': 370,
#  'soov': 371,
#  'uuesti': 372,
#  'esimees': 373,
#  'valmis': 374,
#  'selge': 375,
#  'teater': 376,
#  'vähe': 377,
#  'kolmas': 378,
#  'kõrvale': 379,
#  'kõnelema': 380,
#  'tühi': 381,
#  'siia': 382,
#  'samm': 383,
#  'pöörduma': 384,
#  'õhk': 385,
#  'liikuma': 386,
#  'teatama': 387,
#  'jooksma': 388,
#  'otsa': 389,
#  'pöörama': 390,
#  'suvi': 391,
#  'kirjandus': 392,
#  'korral': 393,
#  'kevad': 394,
#  'tähtis': 395,
#  'seni': 396,
#  'taevas': 397,
#  'sõber': 398,
#  'leping': 399,
#  'magama': 400,
#  'paistma': 401,
#  'kaotama': 402,
#  'koguni': 403,
#  'kaudu': 404,
#  'paluma': 405,
#  'i': 406,
#  'kindlasti': 407,
#  'alt': 408,
#  'võim': 409,
#  'jooma': 410,
#  'uurima': 411,
#  'mäletama': 412,
#  'sündima': 413,
#  'kostma': 414,
#  'hulgas': 415,
#  'tegu': 416,
#  'ligi': 417,
#  'olev': 418,
#  'puuduma': 419,
#  'loom': 420,
#  'vorm': 421,
#  'külm': 422,
#  'üksnes': 423,
#  'materjal': 424,
#  'avama': 425,
#  'leht': 426,
#  'veidi': 427,
#  'm': 428,
#  'ajalugu': 429,
#  'kinnitama': 430,
#  'mil': 431,
#  'tugev': 432,
#  'kuulama': 433,
#  'vähem': 434,
#  'võrdlema': 435,
#  'enamasti': 436,
#  'keha': 437,
#  'seadma': 438,
#  'ajaleht': 439,
#  'protsent': 440,
#  'tuhat': 441,
#  'suu': 442,
#  'tuntud': 443,
#  'läti': 444,
#  'sööma': 445,
#  'küla': 446,
#  'väiksem': 447,
#  'vaba': 448,
#  'saksamaa': 449,
#  'üksik': 450,
#  'kasvatama': 451,
#  'jüri': 452,
#  'jne': 453,
#  'toime': 454,
#  'järel': 455,
#  'sundima': 456,
#  'küllap': 457,
#  'soe': 458,
#  'müüma': 459,
#  'sügis': 460,
#  'peremees': 461,
#  'pisut': 462,
#  'rootsi': 463,
#  'süda': 464,
#  'praegune': 465,
#  'korraldama': 466,
#  'klass': 467,
#  'heitma': 468,
#  'lõpuks': 469,
#  'armastus': 470,
#  'kohal': 471,
#  'kunstnik': 472,
#  'võit': 473,
#  'märkima': 474,
#  'kerge': 475,
#  'vahele': 476,
#  'tõepoolest': 477,
#  'sellepärast': 478,
#  'laev': 479,
#  'keskmine': 480,
#  'lahkuma': 481,
#  'perekond': 482,
#  'rida': 483,
#  'komme': 484,
#  'joon': 485,
#  'palk': 486,
#  'kuju': 487,
#  'lausa': 488,
#  'piir': 489,
#  'asemel': 490,
#  'nimelt': 491,
#  'põhi': 492,
#  'paik': 493,
#  'vastus': 494,
#  'tütar': 495,
#  'hoone': 496,
#  'ilus': 497,
#  'liikumine': 498,
#  'veelgi': 499,
#  'amet': 500,
#  'vedama': 501,
#  'loodus': 502,
#  'õpilane': 503,
#  'hind': 504,
#  'korter': 505,
#  'kujutama': 506,
#  'lükkama': 507,
#  'paremini': 508,
#  'ala': 509,
#  'päike': 510,
#  'muutma': 511,
#  'kuus': 512,
#  'direktor': 513,
#  'saar': 514,
#  'abi': 515,
#  'plaan': 516,
#  'algul': 517,
#  'vabadus': 518,
#  'soovima': 519,
#  'rubla': 520,
#  'huvitav': 521,
#  'hirm': 522,
#  'ehitama': 523,
#  'korraga': 524,
#  'tarvis': 525,
#  'kõrv': 526,
#  'puhas': 527,
#  'õpetama': 528,
#  'lihtne': 529,
#  'muusika': 530,
#  'tervis': 531,
#  'eestlane': 532,
#  'tõsi': 533,
#  'vend': 534,
#  'mägi': 535,
#  'teadus': 536,
#  's': 537,
#  'vaikne': 538,
#  'koer': 539,
#  'rahu': 540,
#  'j.': 541,
#  'antud': 542,
#  'haarama': 543,
#  'avalik': 544,
#  'ettepanek': 545,
#  'õlg': 546,
#  'juhtima': 547,
#  'kuidagi': 548,
#  'kohale': 549,
#  'seepärast': 550,
#  'taha': 551,
#  'pääsema': 552,
#  'muld': 553,
#  'viskama': 554,
#  'toetama': 555,
#  'võimalikult': 556,
#  'tuul': 557,
#  'vara': 558,
#  'tänu': 559,
#  'ühine': 560,
#  'tähtsus': 561,
#  'lendama': 562,
#  'kaitsma': 563,
#  'soovitama': 564,
#  'lugeja': 565,
#  'kael': 566,
#  'suruma': 567,
#  'võitlus': 568,
#  'tabama': 569,
#  'surm': 570,
#  'jaan': 571,
#  'sündmus': 572,
#  'kunst': 573,
#  'kasu': 574,
#  'sada': 575,
#  'paber': 576,
#  'punkt': 577,
#  'puutuma': 578,
#  'jumal': 579,
#  'kivi': 580,
#  'naerma': 581,
#  'kasv': 582,
#  'ots': 583,
#  'vähene': 584,
#  'võitma': 585,
#  'põrand': 586,
#  'talu': 587,
#  'varsti': 588,
#  'taim': 589,
#  'keerama': 590,
#  'tagant': 591,
#  'kahju': 592,
#  'programm': 593,
#  'viga': 594,
#  'juuli': 595,
#  'üksteise': 596,
#  'juhataja': 597,
#  'koguma': 598,
#  'öö': 599,
#  'minister': 600,
#  'number': 601,
#  'tuli': 602,
#  'lausuma': 603,
#  'muidu': 604,
#  'kirjanik': 605,
#  'ülikool': 606,
#  'valimine': 607,
#  'kust': 608,
#  'september': 609,
#  'piim': 610,
#  'viibima': 611,
#  'elanik': 612,
#  'uurimine': 613,
#  'abil': 614,
#  'lind': 615,
#  'n': 616,
#  'külaline': 617,
#  'ainus': 618,
#  'pank': 619,
#  'juus': 620,
#  'teatud': 621,
#  'põld': 622,
#  'teineteise': 623,
#  'õieti': 624,
#  'poolest': 625,
#  'kiiresti': 626,
#  'sinine': 627,
#  'suurus': 628,
#  'küllalt': 629,
#  'pere': 630,
#  'kallas': 631,
#  'mõjuma': 632,
#  'sees': 633,
#  'siit': 634,
#  'mõnikord': 635,
#  'uni': 636,
#  'üksi': 637,
#  'järgnema': 638,
#  'suurendama': 639,
#  'natuke': 640,
#  'kaua': 641,
#  'kallis': 642,
#  'tõde': 643,
#  'segama': 644,
#  'kaitse': 645,
#  'vari': 646,
#  'mälestus': 647,
#  'leib': 648,
#  'lai': 649,
#  'nimetatud': 650,
#  'tõsine': 651,
#  'saadud': 652,
#  'avaldus': 653,
#  'pime': 654,
#  'ammu': 655,
#  'täitmine': 656,
#  'tulevik': 657,
#  'õu': 658,
#  'arutama': 659,
#  'hall': 660,
#  'ilm': 661,
#  'seletama': 662,
#  'mure': 663,
#  'mitmesugune': 664,
#  'lõikama': 665,
#  'kodanik': 666,
#  'talv': 667,
#  'summa': 668,
#  'vaevalt': 669,
#  'märk': 670,
#  'juuni': 671,
#  'jagama': 672,
#  'nurk': 673,
#  'seitse': 674,
#  'järv': 675,
#  'kõndima': 676,
#  'nr': 677,
#  'nutma': 678,
#  'tükk': 679,
#  'hobune': 680,
#  'sisu': 681,
#  'kaup': 682,
#  'selguma': 683,
#  'hüüdma': 684,
#  'iseenese': 685,
#  'seekord': 686,
#  'lääs': 687,
#  'sakslane': 688,
#  'ääres': 689,
#  'haige': 690,
#  'tume': 691,
#  'pealinn': 692,
#  'teisiti': 693,
#  'mai': 694,
#  'toon': 695,
#  'pind': 696,
#  'lõppema': 697,
#  'lumi': 698,
#  'asutus': 699,
#  'voodi': 700,
#  'värav': 701,
#  'aina': 702,
#  'vahetama': 703,
#  'säärane': 704,
#  'vaim': 705,
#  'kiire': 706,
#  'komisjon': 707,
#  'igaüks': 708,
#  'laul': 709,
#  'mari': 710,
#  'koosolek': 711,
#  'klaas': 712,
#  'hulka': 713,
#  'november': 714,
#  'edu': 715,
#  'noormees': 716,
#  'lühike': 717,
#  'õnn': 718,
#  'seesama': 719,
#  'jõgi': 720,
#  'halb': 721,
#  'minut': 722,
#  'veri': 723,
#  'pudel': 724,
#  'kirik': 725,
#  'saal': 726,
#  'millal': 727,
#  'balti': 728,
#  'nõue': 729,
#  'mõju': 730,
#  'saatus': 731,
#  'politsei': 732,
#  'nina': 733,
#  'raskus': 734,
#  'kukkuma': 735,
#  'külg': 736,
#  'vaikima': 737,
#  'nõu': 738,
#  'tihti': 739,
#  'rind': 740,
#  'mõis': 741,
#  'm.': 742,
#  'arst': 743,
#  'kaunis': 744,
#  'pehme': 745,
#  'kuum': 746,
#  'valgus': 747,
#  'laulma': 748,
#  'kõlama': 749,
#  'pealt': 750,
#  'kumbki': 751,
#  'aed': 752,
#  'r': 753,
#  'sügav': 754,
#  'sõrm': 755,
#  'toit': 756,
#  'kuulutama': 757,
#  'puudutama': 758,
#  'keelama': 759,
#  'kõne': 760,
#  'väärtus': 761,
#  'vanamees': 762,
#  'korraks': 763,
#  'trepp': 764,
#  'teenima': 765,
#  'täielikult': 766,
#  'valitsema': 767,
#  'näitus': 768,
#  'hindama': 769,
#  'narva': 770,
#  'ah': 771,
#  'äratama': 772,
#  'tagajärg': 773,
#  'vili': 774,
#  'surnud': 775,
#  'abinõu': 776,
#  'armastama': 777,
#  'vahtima': 778,
#  'tänane': 779,
#  'kusagil': 780,
#  'õis': 781,
#  'juhatus': 782,
#  'roheline': 783,
#  'vastane': 784,
#  'määrama': 785,
#  'rõõm': 786,
#  'juhan': 787,
#  'kala': 788,
#  'katus': 789,
#  'katma': 790,
#  'saamine': 791,
#  'senine': 792,
#  'kongress': 793,
#  'omanik': 794,
#  'kott': 795,
#  'g': 796,
#  'lootus': 797,
#  'liha': 798,
#  'e': 799,
#  'võimatu': 800,
#  'köök': 801,
#  'vahelt': 802,
#  'tasku': 803,
#  'kiirus': 804,
#  'ühtlasi': 805,
#  'selts': 806,
#  'karl': 807,
#  'hoolimata': 808,
#  'nähtus': 809,
#  'detsember': 810,
#  'pärima': 811,
#  'ükskõik': 812,
#  'vaene': 813,
#  'kõrgem': 814,
#  'tööline': 815,
#  'side': 816,
#  'vaatamata': 817,
#  'igatahes': 818,
#  'aprill': 819,
#  'b': 820,
#  'vanaema': 821,
#  'kiskuma': 822,
#  'madal': 823,
#  'tähendus': 824,
#  'osakond': 825,
#  'elav': 826,
#  'noorem': 827,
#  'püsti': 828,
#  'vahe': 829,
#  'pikem': 830,
#  'tõsiselt': 831,
#  'haigus': 832,
#  'paul': 833,
#  'seas': 834,
#  'kuritegu': 835,
#  'iseloom': 836,
#  'määratud': 837,
#  'tähtsam': 838,
#  'hool': 839,
#  'ümbrus': 840,
#  'k': 841,
#  'kaugel': 842,
#  'kaheksa': 843,
#  'kippuma': 844,
#  'peeter': 845,
#  'tihe': 846,
#  'kauge': 847,
#  'tõlge': 848,
#  'kurat': 849,
#  'teade': 850,
#  'parandama': 851,
#  'riie': 852,
#  'kurb': 853,
#  'liik': 854,
#  'professor': 855,
#  'värv': 856,
#  'sõit': 857,
#  'noh': 858,
#  'põlema': 859,
#  'valmistama': 860,
#  'jaak': 861,
#  'hammas': 862,
#  'kartul': 863,
#  'ilmunud': 864,
#  'ärkama': 865,
#  'põhjal': 866,
#  'valu': 867,
#  'paks': 868,
#  'viin': 869,
#  'pealegi': 870,
#  'katsuma': 871,
#  'lähenema': 872,
#  'liiv': 873,
#  'kiitma': 874,
#  'tungima': 875,
#  'kätte': 876,
#  'ajalooline': 877,
#  'imelik': 878,
#  'naeratama': 879,
#  'v': 880,
#  'imestama': 881,
#  'ring': 882,
#  'kaarel': 883,
#  'ajakirjandus': 884,
#  'r.': 885,
#  'oh': 886,
#  'dollar': 887,
#  'teadmine': 888,
#  'kerkima': 889,
#  'õnnelik': 890,
#  'masin': 891,
#  't': 892,
#  'tutvustama': 893,
#  'märts': 894,
#  'lehm': 895,
#  'rippuma': 896,
#  'kahtlema': 897,
#  'ii': 898,
#  'harjuma': 899,
#  'julgema': 900,
#  'eestimaa': 901,
#  'abielu': 902,
#  'muna': 903,
#  'kodune': 904,
#  'tulevane': 905,
#  'rikkuma': 906,
#  'vajuma': 907,
#  'kitsas': 908,
#  'loomulik': 909,
#  'varjama': 910,
#  'vahest': 911,
#  'ehitus': 912,
#  'tantsima': 913,
#  'silmitsema': 914,
#  'kannatama': 915,
#  'luba': 916,
#  'omadus': 917,
#  'ahi': 918,
#  'e.': 919,
#  'tegelane': 920,
#  'kass': 921,
#  'korjama': 922,
#  'kuulus': 923,
#  'ronima': 924,
#  'niisama': 925,
#  'jutustama': 926,
#  'pistma': 927,
#  'kahjuks': 928,
#  'missugune': 929,
#  'nahk': 930,
#  'j': 931,
#  'p': 932,
#  'iseseisev': 933,
#  'inglise': 934,
#  'lähedal': 935,
#  'surema': 936,
#  'tool': 937,
#  'mõistus': 938,
#  'kuiv': 939,
#  'prantsuse': 940,
#  'käesolev': 941,
#  'turg': 942,
#  'no': 943,
#  'ungari': 944,
#  'kollane': 945,
#  'ainuke': 946,
#  'väljas': 947,
#  'korraldus': 948,
#  'k.': 949,
#  'lill': 950,
#  'tasu': 951,
#  'serv': 952,
#  'kaal': 953,
#  'kõvasti': 954,
#  'vald': 955,
#  'puudus': 956,
#  'korralik': 957,
#  'peagi': 958,
#  'läbirääkimine': 959,
#  'hiljuti': 960,
#  'rada': 961,
#  'etendus': 962,
#  'tulev': 963,
#  'h.': 964,
#  'naer': 965,
#  'muretsema': 966,
#  'kestma': 967,
#  'saadik': 968,
#  'parandamine': 969,
#  'takistama': 970,
#  'vaheline': 971,
#  'vähenema': 972,
#  'sugugi': 973,
#  'leppima': 974,
#  'vaenlane': 975,
#  'järeldus': 976,
#  'perenaine': 977,
#  'pärnu': 978,
#  'märg': 979,
#  'neljas': 980,
#  'teatav': 981,
#  'hele': 982,
#  'eemal': 983,
#  'harva': 984,
#  'külge': 985,
#  'hirmus': 986,
#  'dokument': 987,
#  'tänavu': 988,
#  'lõuna': 989,
#  'protsess': 990,
#  'lause': 991,
#  'inglismaa': 992,
#  'lagi': 993,
#  'kaugele': 994,
#  'kordama': 995,
#  'peetud': 996,
#  'hiina': 997,
#  'käik': 998,
#  'täielik': 999,
#  ...}

# %%
keys = aligned_svd_models[ref_year].vocabulary
#idxs = aligned_svd_models[1970].wv.index_to_key

# %%
all_words
# Out:
# ['olema',
#  'ja',
#  'tema',
#  'see',
#  'ei',
#  'mina',
#  'kui',
#  'et',
#  'mis',
#  'ka',
#  'oma',
#  'aga',
#  'ning',
#  'saama',
#  'tulema',
#  'nii',
#  'ise',
#  'pidama',
#  'kes',
#  'aasta',
#  'või',
#  'siis',
#  'üks',
#  'sina',
#  'minema',
#  'võima',
#  'tegema',
#  'teine',
#  'nagu',
#  'ütlema',
#  'aeg',
#  'võtma',
#  'kõik',
#  'veel',
#  'mees',
#  'juba',
#  'suur',
#  'eesti',
#  'inimene',
#  'ära',
#  'jääma',
#  'teadma',
#  'välja',
#  'kas',
#  'kuid',
#  'andma',
#  'nägema',
#  'hakkama',
#  'mitte',
#  'üle',
#  'miski',
#  'töö',
#  'nüüd',
#  'palju',
#  'kord',
#  'vaid',
#  'iga',
#  'uus',
#  'mõni',
#  'siin',
#  'sest',
#  'küll',
#  'ju',
#  'kaks',
#  'tahtma',
#  'kus',
#  'enam',
#  'väga',
#  'panema',
#  'pärast',
#  'vaatama',
#  'ainult',
#  'ikka',
#  'käima',
#  'seal',
#  'esimene',
#  'rääkima',
#  'vastu',
#  'tundma',
#  'ega',
#  'päev',
#  'hea',
#  'kuidas',
#  'eest',
#  'peale',
#  'käsi',
#  'naine',
#  'tagasi',
#  'asi',
#  'a',
#  'silm',
#  'enne',
#  'kõige',
#  'osa',
#  'viimane',
#  'sama',
#  'sõna',
#  'mõtlema',
#  'elu',
#  'mingi',
#  'kogu',
#  'rohkem',
#  'maa',
#  'tallinn',
#  'jõudma',
#  'laps',
#  'leidma',
#  'ette',
#  'arvama',
#  'mitu',
#  'kolm',
#  'poole',
#  'pool',
#  'elama',
#  'istuma',
#  'tooma',
#  'koos',
#  'seisma',
#  'all',
#  'jätma',
#  'ema',
#  'kohta',
#  'läbi',
#  'linn',
#  'maja',
#  'kuulma',
#  'just',
#  'ees',
#  'praegu',
#  'isegi',
#  'keegi',
#  'pea',
#  'mõte',
#  'tee',
#  'kuni',
#  'suurem',
#  'oskama',
#  'noor',
#  'edasi',
#  'riik',
#  'poolt',
#  'vaja',
#  'viis',
#  'vahel',
#  'niisugune',
#  'jalg',
#  'laskma',
#  'juht',
#  'koht',
#  'siiski',
#  'küsima',
#  'kindel',
#  'väike',
#  'suutma',
#  'valge',
#  'lõpp',
#  'püüdma',
#  'viima',
#  'vana',
#  'kodu',
#  'kohe',
#  'lugema',
#  'alles',
#  'kirjutama',
#  'üles',
#  'miks',
#  'juurde',
#  'muu',
#  'pikk',
#  'uks',
#  'ehk',
#  'valitsus',
#  'keel',
#  'raske',
#  'algus',
#  'kaasa',
#  'poiss',
#  'hästi',
#  'muutuma',
#  'vesi',
#  'võimalik',
#  'kokku',
#  'lööma',
#  'alla',
#  'alus',
#  'vastama',
#  'alati',
#  'ootama',
#  'hiljem',
#  'küsimus',
#  'maailm',
#  'tartu',
#  'tegevus',
#  'rahvas',
#  'nõudma',
#  'hoopis',
#  'isa',
#  'hääl',
#  'astuma',
#  'muidugi',
#  'tuba',
#  'nägu',
#  'raha',
#  'kinni',
#  'mööda',
#  'näitama',
#  'hoidma',
#  'maha',
#  'tekkima',
#  'sisse',
#  'jõud',
#  'juures',
#  'ometi',
#  'lubama',
#  'kuigi',
#  'miljon',
#  'asuma',
#  'algama',
#  'taga',
#  'aitama',
#  'töötama',
#  'sõitma',
#  'ümber',
#  'jooksul',
#  'tohtima',
#  'parem',
#  'peaaegu',
#  'liiga',
#  'kunagi',
#  'jälle',
#  'lahti',
#  'aru',
#  'mõlema',
#  'paar',
#  'nimi',
#  'ajama',
#  'kiri',
#  'järele',
#  'uskuma',
#  'jutt',
#  'meel',
#  'moskva',
#  'täis',
#  'üsna',
#  'õige',
#  'saatma',
#  'ilma',
#  'järgmine',
#  'puhul',
#  'mõistma',
#  'raamat',
#  'täiesti',
#  'kool',
#  'tegemine',
#  'jaoks',
#  'must',
#  'ilmuma',
#  'too',
#  'tüdruk',
#  'nõnda',
#  'jah',
#  'kuhu',
#  'kell',
#  'tänav',
#  'ruum',
#  'tähendama',
#  'kutsuma',
#  'ülesanne',
#  'otsima',
#  'pilk',
#  'meri',
#  'kaduma',
#  'päris',
#  'täitma',
#  'sinna',
#  'tõusma',
#  'soome',
#  'hulk',
#  '',
#  'terve',
#  'laud',
#  'tehtud',
#  'mängima',
#  'maksma',
#  'neli',
#  'endine',
#  'looma',
#  'umbes',
#  'kõrval',
#  'ettevõte',
#  'juhtuma',
#  'seadus',
#  'tunnistama',
#  'poeg',
#  'tõstma',
#  'president',
#  'tõmbama',
#  'langema',
#  'vist',
#  'vähemalt',
#  'liige',
#  'hing',
#  'tund',
#  'õigus',
#  'kandma',
#  'alustama',
#  'lugu',
#  'kasvama',
#  'kümme',
#  'tõttu',
#  'selg',
#  'lootma',
#  'täna',
#  'kuu',
#  'ringi',
#  'valima',
#  'kartma',
#  'õhtu',
#  'kuna',
#  'õppima',
#  'partei',
#  'otsus',
#  'lihtsalt',
#  'punane',
#  'varem',
#  'lisama',
#  'näima',
#  'vanem',
#  'kuuluma',
#  'pilt',
#  'aken',
#  'kohalik',
#  'eks',
#  'sõda',
#  'seisukoht',
#  'mets',
#  'kroon',
#  'avaldama',
#  'a.',
#  'nimetama',
#  'sattuma',
#  'tuttav',
#  'lõpetama',
#  'mäng',
#  'kõrge',
#  'ajal',
#  'otsustama',
#  'peal',
#  'august',
#  'võõras',
#  'unustama',
#  'otse',
#  'seega',
#  'põhjus',
#  'tõesti',
#  'ostma',
#  'vabariik',
#  'nädal',
#  'sein',
#  'sealt',
#  'puu',
#  'leiduma',
#  'eesmärk',
#  'kohus',
#  'saksa',
#  'hommik',
#  'märkama',
#  'pakkuma',
#  'meeldima',
#  'arv',
#  'õpetaja',
#  'soov',
#  'uuesti',
#  'esimees',
#  'valmis',
#  'selge',
#  'teater',
#  'vähe',
#  'kolmas',
#  'kõrvale',
#  'kõnelema',
#  'tühi',
#  'siia',
#  'samm',
#  'pöörduma',
#  'õhk',
#  'liikuma',
#  'teatama',
#  'jooksma',
#  'otsa',
#  'pöörama',
#  'suvi',
#  'kirjandus',
#  'korral',
#  'kevad',
#  'tähtis',
#  'seni',
#  'taevas',
#  'sõber',
#  'leping',
#  'magama',
#  'paistma',
#  'kaotama',
#  'koguni',
#  'kaudu',
#  'paluma',
#  'i',
#  'kindlasti',
#  'alt',
#  'võim',
#  'jooma',
#  'uurima',
#  'mäletama',
#  'sündima',
#  'kostma',
#  'hulgas',
#  'tegu',
#  'ligi',
#  'olev',
#  'puuduma',
#  'loom',
#  'vorm',
#  'külm',
#  'üksnes',
#  'materjal',
#  'avama',
#  'leht',
#  'veidi',
#  'm',
#  'ajalugu',
#  'kinnitama',
#  'mil',
#  'tugev',
#  'kuulama',
#  'vähem',
#  'võrdlema',
#  'enamasti',
#  'keha',
#  'seadma',
#  'ajaleht',
#  'protsent',
#  'tuhat',
#  'suu',
#  'tuntud',
#  'läti',
#  'sööma',
#  'küla',
#  'väiksem',
#  'vaba',
#  'saksamaa',
#  'üksik',
#  'kasvatama',
#  'jüri',
#  'jne',
#  'toime',
#  'järel',
#  'sundima',
#  'küllap',
#  'soe',
#  'müüma',
#  'sügis',
#  'peremees',
#  'pisut',
#  'rootsi',
#  'süda',
#  'praegune',
#  'korraldama',
#  'klass',
#  'heitma',
#  'lõpuks',
#  'armastus',
#  'kohal',
#  'kunstnik',
#  'võit',
#  'märkima',
#  'kerge',
#  'vahele',
#  'tõepoolest',
#  'sellepärast',
#  'laev',
#  'keskmine',
#  'lahkuma',
#  'perekond',
#  'rida',
#  'komme',
#  'joon',
#  'palk',
#  'kuju',
#  'lausa',
#  'piir',
#  'asemel',
#  'nimelt',
#  'põhi',
#  'paik',
#  'vastus',
#  'tütar',
#  'hoone',
#  'ilus',
#  'liikumine',
#  'veelgi',
#  'amet',
#  'vedama',
#  'loodus',
#  'õpilane',
#  'hind',
#  'korter',
#  'kujutama',
#  'lükkama',
#  'paremini',
#  'ala',
#  'päike',
#  'muutma',
#  'kuus',
#  'direktor',
#  'saar',
#  'abi',
#  'plaan',
#  'algul',
#  'vabadus',
#  'soovima',
#  'rubla',
#  'huvitav',
#  'hirm',
#  'ehitama',
#  'korraga',
#  'tarvis',
#  'kõrv',
#  'puhas',
#  'õpetama',
#  'lihtne',
#  'muusika',
#  'tervis',
#  'eestlane',
#  'tõsi',
#  'vend',
#  'mägi',
#  'teadus',
#  's',
#  'vaikne',
#  'koer',
#  'rahu',
#  'j.',
#  'antud',
#  'haarama',
#  'avalik',
#  'ettepanek',
#  'õlg',
#  'juhtima',
#  'kuidagi',
#  'kohale',
#  'seepärast',
#  'taha',
#  'pääsema',
#  'muld',
#  'viskama',
#  'toetama',
#  'võimalikult',
#  'tuul',
#  'vara',
#  'tänu',
#  'ühine',
#  'tähtsus',
#  'lendama',
#  'kaitsma',
#  'soovitama',
#  'lugeja',
#  'kael',
#  'suruma',
#  'võitlus',
#  'tabama',
#  'surm',
#  'jaan',
#  'sündmus',
#  'kunst',
#  'kasu',
#  'sada',
#  'paber',
#  'punkt',
#  'puutuma',
#  'jumal',
#  'kivi',
#  'naerma',
#  'kasv',
#  'ots',
#  'vähene',
#  'võitma',
#  'põrand',
#  'talu',
#  'varsti',
#  'taim',
#  'keerama',
#  'tagant',
#  'kahju',
#  'programm',
#  'viga',
#  'juuli',
#  'üksteise',
#  'juhataja',
#  'koguma',
#  'öö',
#  'minister',
#  'number',
#  'tuli',
#  'lausuma',
#  'muidu',
#  'kirjanik',
#  'ülikool',
#  'valimine',
#  'kust',
#  'september',
#  'piim',
#  'viibima',
#  'elanik',
#  'uurimine',
#  'abil',
#  'lind',
#  'n',
#  'külaline',
#  'ainus',
#  'pank',
#  'juus',
#  'teatud',
#  'põld',
#  'teineteise',
#  'õieti',
#  'poolest',
#  'kiiresti',
#  'sinine',
#  'suurus',
#  'küllalt',
#  'pere',
#  'kallas',
#  'mõjuma',
#  'sees',
#  'siit',
#  'mõnikord',
#  'uni',
#  'üksi',
#  'järgnema',
#  'suurendama',
#  'natuke',
#  'kaua',
#  'kallis',
#  'tõde',
#  'segama',
#  'kaitse',
#  'vari',
#  'mälestus',
#  'leib',
#  'lai',
#  'nimetatud',
#  'tõsine',
#  'saadud',
#  'avaldus',
#  'pime',
#  'ammu',
#  'täitmine',
#  'tulevik',
#  'õu',
#  'arutama',
#  'hall',
#  'ilm',
#  'seletama',
#  'mure',
#  'mitmesugune',
#  'lõikama',
#  'kodanik',
#  'talv',
#  'summa',
#  'vaevalt',
#  'märk',
#  'juuni',
#  'jagama',
#  'nurk',
#  'seitse',
#  'järv',
#  'kõndima',
#  'nr',
#  'nutma',
#  'tükk',
#  'hobune',
#  'sisu',
#  'kaup',
#  'selguma',
#  'hüüdma',
#  'iseenese',
#  'seekord',
#  'lääs',
#  'sakslane',
#  'ääres',
#  'haige',
#  'tume',
#  'pealinn',
#  'teisiti',
#  'mai',
#  'toon',
#  'pind',
#  'lõppema',
#  'lumi',
#  'asutus',
#  'voodi',
#  'värav',
#  'aina',
#  'vahetama',
#  'säärane',
#  'vaim',
#  'kiire',
#  'komisjon',
#  'igaüks',
#  'laul',
#  'mari',
#  'koosolek',
#  'klaas',
#  'hulka',
#  'november',
#  'edu',
#  'noormees',
#  'lühike',
#  'õnn',
#  'seesama',
#  'jõgi',
#  'halb',
#  'minut',
#  'veri',
#  'pudel',
#  'kirik',
#  'saal',
#  'millal',
#  'balti',
#  'nõue',
#  'mõju',
#  'saatus',
#  'politsei',
#  'nina',
#  'raskus',
#  'kukkuma',
#  'külg',
#  'vaikima',
#  'nõu',
#  'tihti',
#  'rind',
#  'mõis',
#  'm.',
#  'arst',
#  'kaunis',
#  'pehme',
#  'kuum',
#  'valgus',
#  'laulma',
#  'kõlama',
#  'pealt',
#  'kumbki',
#  'aed',
#  'r',
#  'sügav',
#  'sõrm',
#  'toit',
#  'kuulutama',
#  'puudutama',
#  'keelama',
#  'kõne',
#  'väärtus',
#  'vanamees',
#  'korraks',
#  'trepp',
#  'teenima',
#  'täielikult',
#  'valitsema',
#  'näitus',
#  'hindama',
#  'narva',
#  'ah',
#  'äratama',
#  'tagajärg',
#  'vili',
#  'surnud',
#  'abinõu',
#  'armastama',
#  'vahtima',
#  'tänane',
#  'kusagil',
#  'õis',
#  'juhatus',
#  'roheline',
#  'vastane',
#  'määrama',
#  'rõõm',
#  'juhan',
#  'kala',
#  'katus',
#  'katma',
#  'saamine',
#  'senine',
#  'kongress',
#  'omanik',
#  'kott',
#  'g',
#  'lootus',
#  'liha',
#  'e',
#  'võimatu',
#  'köök',
#  'vahelt',
#  'tasku',
#  'kiirus',
#  'ühtlasi',
#  'selts',
#  'karl',
#  'hoolimata',
#  'nähtus',
#  'detsember',
#  'pärima',
#  'ükskõik',
#  'vaene',
#  'kõrgem',
#  'tööline',
#  'side',
#  'vaatamata',
#  'igatahes',
#  'aprill',
#  'b',
#  'vanaema',
#  'kiskuma',
#  'madal',
#  'tähendus',
#  'osakond',
#  'elav',
#  'noorem',
#  'püsti',
#  'vahe',
#  'pikem',
#  'tõsiselt',
#  'haigus',
#  'paul',
#  'seas',
#  'kuritegu',
#  'iseloom',
#  'määratud',
#  'tähtsam',
#  'hool',
#  'ümbrus',
#  'k',
#  'kaugel',
#  'kaheksa',
#  'kippuma',
#  'peeter',
#  'tihe',
#  'kauge',
#  'tõlge',
#  'kurat',
#  'teade',
#  'parandama',
#  'riie',
#  'kurb',
#  'liik',
#  'professor',
#  'värv',
#  'sõit',
#  'noh',
#  'põlema',
#  'valmistama',
#  'jaak',
#  'hammas',
#  'kartul',
#  'ilmunud',
#  'ärkama',
#  'põhjal',
#  'valu',
#  'paks',
#  'viin',
#  'pealegi',
#  'katsuma',
#  'lähenema',
#  'liiv',
#  'kiitma',
#  'tungima',
#  'kätte',
#  'ajalooline',
#  'imelik',
#  'naeratama',
#  'v',
#  'imestama',
#  'ring',
#  'kaarel',
#  'ajakirjandus',
#  'r.',
#  'oh',
#  'dollar',
#  'teadmine',
#  'kerkima',
#  'õnnelik',
#  'masin',
#  't',
#  'tutvustama',
#  'märts',
#  'lehm',
#  'rippuma',
#  'kahtlema',
#  'ii',
#  'harjuma',
#  'julgema',
#  'eestimaa',
#  'abielu',
#  'muna',
#  'kodune',
#  'tulevane',
#  'rikkuma',
#  'vajuma',
#  'kitsas',
#  'loomulik',
#  'varjama',
#  'vahest',
#  'ehitus',
#  'tantsima',
#  'silmitsema',
#  'kannatama',
#  'luba',
#  'omadus',
#  'ahi',
#  'e.',
#  'tegelane',
#  'kass',
#  'korjama',
#  'kuulus',
#  'ronima',
#  'niisama',
#  'jutustama',
#  'pistma',
#  'kahjuks',
#  'missugune',
#  'nahk',
#  'j',
#  'p',
#  'iseseisev',
#  'inglise',
#  'lähedal',
#  'surema',
#  'tool',
#  'mõistus',
#  'kuiv',
#  'prantsuse',
#  'käesolev',
#  'turg',
#  'no',
#  'ungari',
#  'kollane',
#  'ainuke',
#  'väljas',
#  'korraldus',
#  'k.',
#  'lill',
#  'tasu',
#  'serv',
#  'kaal',
#  'kõvasti',
#  'vald',
#  'puudus',
#  'korralik',
#  'peagi',
#  'läbirääkimine',
#  'hiljuti',
#  'rada',
#  'etendus',
#  'tulev',
#  'h.',
#  'naer',
#  'muretsema',
#  'kestma',
#  'saadik',
#  'parandamine',
#  'takistama',
#  'vaheline',
#  'vähenema',
#  'sugugi',
#  'leppima',
#  'vaenlane',
#  'järeldus',
#  'perenaine',
#  'pärnu',
#  'märg',
#  'neljas',
#  'teatav',
#  'hele',
#  'eemal',
#  'harva',
#  'külge',
#  'hirmus',
#  'dokument',
#  'tänavu',
#  'lõuna',
#  'protsess',
#  'lause',
#  'inglismaa',
#  'lagi',
#  'kaugele',
#  'kordama',
#  'peetud',
#  'hiina',
#  'käik',
#  'täielik',
#  ...]

# %%
vecs = [[None] * len(aligned_svd_models) for i in range(len(all_words))]

# %%
aligned_svd_models[1990].vectors("tere")
# Out:
# (array([-0.05587434, -0.1951355 , -0.08260426,  0.13774018, -0.01712797,
#          0.04574868, -0.02473389, -0.04623565,  0.15354832, -0.03686719,
#         -0.05481276,  0.05318639, -0.05520777, -0.09894572,  0.04152091,
#         -0.08698918, -0.01870924, -0.01662217,  0.07333104, -0.05576035,
#          0.02212026, -0.03710021, -0.13262742,  0.03707617, -0.0099506 ,
#          0.0333817 ,  0.08237399,  0.03535392, -0.01573712,  0.01395037,
#          0.06340759,  0.06202773,  0.00856516,  0.00645246,  0.06215041,
#         -0.05203828,  0.04194363, -0.1218261 ,  0.00947896, -0.05324343,
#         -0.03202885,  0.04130483,  0.01415252,  0.05492151, -0.02720783,
#          0.00536357,  0.01738864, -0.15728112, -0.11027659,  0.0097949 ,
#         -0.05634966,  0.01497706, -0.10478808, -0.0842309 ,  0.06157946,
#          0.00749956, -0.09636088, -0.07610998, -0.07994035,  0.11360342,
#         -0.02883455,  0.00962372, -0.13614418, -0.08060705, -0.04137516,
#          0.08250113,  0.04605633, -0.10614752,  0.06220014, -0.00292943,
#         -0.01808744,  0.01130753,  0.04265871,  0.01688834, -0.03091181,
#         -0.07988577,  0.0026077 ,  0.0825517 , -0.03817165, -0.04871303,
#         -0.10979072,  0.04085657,  0.01922841, -0.07208814, -0.01637514,
#          0.03924885, -0.0294726 ,  0.07603156, -0.12590292, -0.05375581,
#          0.07458754, -0.03356903,  0.0448225 ,  0.0526077 ,  0.06104097,
#         -0.14936117,  0.03901803,  0.07327046, -0.01284538, -0.00037563,
#          0.06941832,  0.06883251,  0.04004154,  0.05159107,  0.02861897,
#         -0.01246646,  0.07935255, -0.10335058, -0.07359693, -0.08424832,
#         -0.0753204 , -0.06145304,  0.00444991,  0.00903501,  0.10527632,
#         -0.00240188,  0.0510048 ,  0.04505258, -0.0696519 , -0.01841748,
#         -0.08349149, -0.06879392, -0.02311785, -0.10448653, -0.02545792,
#         -0.04100643,  0.03119018, -0.18264162, -0.05252259, -0.07887406,
#          0.00739457, -0.02279543,  0.01189446, -0.07559527,  0.06203077,
#         -0.11816806,  0.10145551, -0.03573899, -0.05310219,  0.09838623,
#         -0.06045212, -0.091077  ,  0.06414736, -0.07193097,  0.04104129,
#         -0.02431798,  0.00087507, -0.02596589,  0.13198033,  0.1079755 ,
#         -0.01217911,  0.01213968,  0.00124088,  0.01875815, -0.01226103,
#         -0.02699931,  0.0014491 , -0.01057152,  0.0034793 , -0.02589475,
#          0.00309315, -0.03781288,  0.00382188, -0.00410756,  0.02257186,
#         -0.00021146, -0.00960709, -0.01204738, -0.0145329 ,  0.01470268,
#          0.01168858,  0.01325363,  0.00153591,  0.00500285,  0.02338976,
#          0.00503755, -0.00093574, -0.00274207, -0.00804353,  0.00313079,
#         -0.00093523, -0.00886701,  0.00615225, -0.00280301, -0.0010288 ,
#         -0.00433704, -0.00936913,  0.00064056, -0.00312801, -0.00023246,
#         -0.00116151, -0.00820703, -0.00404167,  0.00309157, -0.00323769,
#          0.00068171, -0.00591252, -0.00943544, -0.01799983,  0.01115907]))

# %%
for i, word in enumerate(all_words):
    for j, decade in enumerate(aligned_svd_models.keys()):
        #print(decade)
        vecs[i][j] = list(aligned_svd_models[decade].vectors(word)[0])

# %%
saveable = {'E': vecs,
    "w": all_words,
    "d": decades}

with open(f'{MODEL_DIR}/svd_a_1890-1990_diachronic.pickle', 'wb') as handle:
    pickle.dump(saveable, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open(f'{MODEL_DIR}/svd_a_1890-1990_diachronic.pickle', 'rb') as handle:
    b = pickle.load(handle)
    
print(saveable == b)
# Out:
# True

# %% [markdown]
# # Evaluating vectors

# %%
rg65 = {("juhe", "naeratus"): 0.02,
    ("kukk", "reis"): 0.04, #voyage - reis
    ("keskpäev", "nöör"): 0.04,
    ("puuvili", "ahi"): 0.05,
    ("autogramm", "kallas"): 0.06,
    ("automobiil", "võlur"): 0.11,
    ("küngas", "pliit"): 0.14,
    ("muigama", "rakendama"): 0.18,
    ("varjupaik", "puuvili"): 0.19,
    ("varjupaik", "munk"): 0.39,
    ("surnuaed", "hullumaja"): 0.42,
    ("klaas", "mustkunstnik"): 0.44,
    ("poiss", "kukk"): 0.44,
    ("padi", "juveel"): 0.45,
    ("munk", "ori"): 0.57,
    ("varjupaik", "kalmistu"): 0.79,
    ("rannik", "mets"): 0.85,
    ("muigama", "noormees"): 0.88,
    ("kallas", "metsamaa"): 0.90,
    ("munk", "oraakel"): 0.91,
    ("poiss", "mõttetark"): 0.96,
    ("automobiil", "padi"): 0.97,
    ("küngas", "kallas"): 0.97,
    ("noormees", "võlur"): 0.99,
    ("mets", "surnuaed"): 1.00,
    ("toit", "kukk"): 1.09,
    ("kalmistu", "metsamaa"): 1.18,
    ("kallas", "reis"): 1.22,
    ("lind", "metsamaa"): 1.24,
    ("rannik", "mägi"): 1.26,
    ("ahi", "rakendama"): 1.37,
    ("kurg", "kukk"): 1.41,
    ("mägi", "metsamaa"): 1.48,
    ("auto", "teekond"): 1.55, #car - journey (teekond)
    ("kalmistu", "küngas"): 1.69,
    ("klaas", "juveel"): 1.78,
    ("mustkunstnik", "oraakel"): 1.82,
    ("kurg", "rakendama"): 2.37,
    ("vend", "noormees"): 2.41,
    ("mõttetark", "võlur"): 2.46,
    ("oraakel", "mõttetark"): 2.61,
    ("lind", "kurg"): 2.63,
    ("lind", "kukk"): 2.63,
    ("toit", "puuvili"): 2.69,
    ("vend", "munk"): 2.74,
    ("varjupaik", "hullumaja"): 3.04,
    ("ahi", "pliit"): 3.11,
    ("mustkunstnik", "võlur"): 3.21,
    ("mägi", "küngas"): 3.29,
    ("juhe", "nöör"): 3.41,
    ("klaas", "trummel"): 3.45,
    ("muigama", "naeratama"): 3.46,
    ("pärisorjus", "ori"): 3.46,
    ("teekond", "reis"): 3.58, #journey - voyage (reis)
    ("autogramm", "allkiri"): 3.59,
    ("rannik", "kallas"): 3.60,
    ("mets", "metsamaa"): 3.65,
    ("rakendama", "tööriist"): 3.66,
    #("cock", "rooster"): 3.68, #the exact same words in Estonian
    ("poiss", "noormees"): 3.82,
    #("cushion", "pillow"): 3.84, #the exact same words in Estonian
    ("kalmistu", "surnuaed"): 3.88,
    ("automobiil", "auto"): 3.92,
    #("midday", "noon"): 3.94, #the exact same words in Estonian
    ("kalliskivi", "juveel"): 3.94}

# %%
for e in [w[1] for w in list(rg65)]:
    print(e)
# Out:
# naeratus
# reis
# nöör
# ahi
# kallas
# võlur
# pliit
# rakendama
# puuvili
# munk
# hullumaja
# mustkunstnik
# kukk
# juveel
# ori
# kalmistu
# mets
# noormees
# metsamaa
# oraakel
# mõttetark
# padi
# kallas
# võlur
# surnuaed
# kukk
# metsamaa
# reis
# metsamaa
# mägi
# rakendama
# kukk
# metsamaa
# teekond
# küngas
# juveel
# oraakel
# rakendama
# noormees
# võlur
# mõttetark
# kurg
# kukk
# puuvili
# munk
# hullumaja
# pliit
# võlur
# küngas
# nöör
# trummel
# naeratama
# ori
# reis
# allkiri
# kallas
# metsamaa
# tööriist
# noormees
# surnuaed
# auto
# juveel

# %%
for v in list(rg65.values()):
    print(v)
# Out:
# 0.02
# 0.04
# 0.04
# 0.05
# 0.06
# 0.11
# 0.14
# 0.18
# 0.19
# 0.39
# 0.42
# 0.44
# 0.44
# 0.45
# 0.57
# 0.79
# 0.85
# 0.88
# 0.9
# 0.91
# 0.96
# 0.97
# 0.97
# 0.99
# 1.0
# 1.09
# 1.18
# 1.22
# 1.24
# 1.26
# 1.37
# 1.41
# 1.48
# 1.55
# 1.69
# 1.78
# 1.82
# 2.37
# 2.41
# 2.46
# 2.61
# 2.63
# 2.63
# 2.69
# 2.74
# 3.04
# 3.11
# 3.21
# 3.29
# 3.41
# 3.45
# 3.46
# 3.46
# 3.58
# 3.59
# 3.6
# 3.65
# 3.66
# 3.82
# 3.88
# 3.92
# 3.94

# %%
aligned_models
# Out:
# {1890: <gensim.models.word2vec.Word2Vec at 0x11e608abdf0>,
#  1900: <gensim.models.word2vec.Word2Vec at 0x11e2150c4f0>,
#  1910: <gensim.models.word2vec.Word2Vec at 0x11e581e9250>,
#  1930: <gensim.models.word2vec.Word2Vec at 0x11e581e98b0>,
#  1950: <gensim.models.word2vec.Word2Vec at 0x11e581e91c0>,
#  1960: <gensim.models.word2vec.Word2Vec at 0x11e581e9070>,
#  1970: <gensim.models.word2vec.Word2Vec at 0x11e21d0bfd0>,
#  1980: <gensim.models.word2vec.Word2Vec at 0x11e21d0b640>,
#  1990: <gensim.models.word2vec.Word2Vec at 0x11e21d0b5b0>}

# %%
#word2vec

def evaluate_word2vec(models):
    c = 0
    for decade in decades:
        print(decade, end = " ")
        model_i = models[decade]

        rg_sim = [] # Rubenstein & Goodenough ground truth similarities
        calc_sim = [] # Calculated similarities for the model
        for w1,w2 in rg65:
            #print(w1, w2)
            if w1 in model_i.wv and w2 in model_i.wv: # Only calculate/find similarities if both words in vocabulary
                calc_sim.append(model_i.wv.similarity(w1, w2))
                rg_sim.append(rg65[(w1,w2)])
        c += pearsonr(calc_sim, rg_sim)[0]
        print(pearsonr(calc_sim, rg_sim))
    return c / len(decades) #Average over all Pearson correlations

evaluate_word2vec(models)
# Out:
# 1890 (0.2796759476857532, 0.4048868323151496)
# 1900 (0.7497101310517166, 0.02001698035815378)
# 1910 (0.6419452258705292, 0.16935294419687294)
# 1930 (0.09219599228435847, 0.6756605141168575)
# 1950 (-0.09327659890855272, 0.761823320426157)
# 1960 (0.6502813100866606, 0.02205284402105857)
# 1970 (0.325463333931819, 0.18753044657904436)
# 1980 (0.22382881145730327, 0.21050418655170539)
# 1990 (0.26902451506500447, 0.13651618229852516)
# 0.3487609631693991

# %%
cosine(aligned_svd_models[1900].vectors("eesti")[0], aligned_svd_models[1910].vectors("eesti")[0])
# Out:
# 1.0010308129600733

# %%
aligned_svd_models
# Out:
# {1890: <svd2vec.core.svd2vec at 0x11e58d86b20>,
#  1900: <svd2vec.core.svd2vec at 0x11e58d86340>,
#  1910: <svd2vec.core.svd2vec at 0x11e58d867f0>,
#  1930: <svd2vec.core.svd2vec at 0x11e58d869d0>,
#  1950: <svd2vec.core.svd2vec at 0x11e58d86af0>,
#  1960: <svd2vec.core.svd2vec at 0x11e58d86460>,
#  1970: <svd2vec.core.svd2vec at 0x11e58d86580>,
#  1980: <svd2vec.core.svd2vec at 0x11e58d86430>,
#  1990: <svd2vec.core.svd2vec at 0x11e58d86ca0>}

# %%
#SVD

def evaluate_ppmisvd(svd_models):
    c = 0

    for decade, model_i in svd_models.items():
        print(decade, end = " ")
        rg_sim = []
        calc_sim = []
        for w1,w2 in rg65:
            if w1 in model_i.words and w2 in model_i.words:
                calc_sim.append(model_i.similarity(w1, w2))
                rg_sim.append(rg65[(w1,w2)])
        c += pearsonr(calc_sim, rg_sim)[0]
        print(pearsonr(calc_sim, rg_sim))
    return c / len(svd_models)

evaluate_ppmisvd(svd_models)
# Out:
# 1890 (0.2463029341117754, 0.34060364255315434)
# 1900 (0.09006529443663089, 0.7495680482422213)
# 1910 (0.47654387651696983, 0.01602488014774559)
# 1930 (0.15228887549115777, 0.45767419105155105)
# 1950 (0.18332664276840116, 0.4263564860094457)
# 1960 (0.17482500216838837, 0.4877802571699536)
# 1970 (0.2181701765186414, 0.31727515014646435)
# 1980 (0.02188268644766417, 0.8878767560158614)
# 1990 (-0.02435327934338869, 0.886233394397038)
# 0.1710058010129156
